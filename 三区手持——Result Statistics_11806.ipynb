# %%
"""
针对不同版本的三区手持眼底图像自动标注病灶区的算法结果进行统计。
@author:By Yale_yang 
Dec. 5th 2019
"""

# %% [markdown]
# # 业务逻辑：
# 1. 关键的数据列：医生的诊断结果（doc）,算法判断结果（v3.4.1），筛查结果（即：基于医生的诊断结果，修改算法”doc“判断为阳性，医生诊断为阴性，但经人工审核后，图像确实存在病灶！此时将”doc“列对应的图片结果修改为阳性，其余与”doc“结果保持一致，修改后的列作为最终的筛查结果列）
# 2. 关键步骤：提取算法”doc“判断为阳性，医生诊断为阴性的图片，进行下一步人工审核；

# %%
import re
import os 
import shutil  #拷贝数据的模块
import pandas as pd 
import matplotlib.pyplot as plt
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
pd.set_option('expand_frame_repr',False)   #禁止自动换行
print('import succed!')
# Out:
# import succed!

# %%
input_path = r'/Users/edz/Documents/My-work/Daily_work/算法结果统计/mine/导入Data'
df_template_file = r'/三区域-异常算法-指标统计-2019总表.xls'   # 统计的样表数据
df_sf = r'/result_11806_suan.csv'  # 算法每次更新的结果数据——需修改

# %%
# 文件读入
df_sf = pd.read_csv(input_path+df_sf, sep=',', index_col=None)   # 算法结果
# df_sf.drop(columns=[1,3,5,7],inplace=True)

df_sf.head()
# Out:
#                              image_name  health_or_not  optic  macular  retina
# 0  0007d2d5b8edab9ed073d17ee5a29719.jpg              0      0        0       0
# 1  000cd9c8584700deff0501f435c8a58b.jpg              0      0        0       0
# 2  00180a4859798d6a363d7336efde531f.jpg              0      0        0       0
# 3  001cd46d9b89095ccdf7a7d518cb9279.jpg              0      0        0       0
# 4  0021fc2480706a742402eb29cac6ff80.jpg              0      0        0       0

# %%
df_sf.rename(columns={'image_name':'md5','health_or_not':'Arithmetic_result',
                      'optic':'item_1','macular':'item_2','retina':'item_3'},inplace=True)
print(df_sf.head())
# Out:
#                                     md5  Arithmetic_result  item_1  item_2  item_3
# 0  0007d2d5b8edab9ed073d17ee5a29719.jpg                  0       0       0       0
# 1  000cd9c8584700deff0501f435c8a58b.jpg                  0       0       0       0
# 2  00180a4859798d6a363d7336efde531f.jpg                  0       0       0       0
# 3  001cd46d9b89095ccdf7a7d518cb9279.jpg                  0       0       0       0
# 4  0021fc2480706a742402eb29cac6ff80.jpg                  0       0       0       0

# %%
df_sf['item_sum'] = df_sf.loc[:,['item_1','item_2','item_3']].apply(lambda x:x.sum(),axis=1)   #'item_sum'列计算'item_1','item_2','item_3'三列的总和

# %%
#df_sf.loc[df_sf['item_sum']>0,:]   # 验证添加的求和列结果正确

# %%
# 根据'item_1','item_2','item_3'中有一项结果为1，则最终的”decison_last“应该标记为”1“，来验证”decison_last“列的数据是否存在错误
for i in range(len(df_sf['md5'])):
    if df_sf.at[i,'item_sum'] > 0:
        if df_sf.at[i,'Arithmetic_result'] == 1:
            pass
        else:
            print("{} index of Arithmetic_result_阳性 is Error! ".format(i))
    else:
        if df_sf.at[i,'Arithmetic_result'] == 0:
            pass
        else:
            print("{} index of Arithmetic_result_阴性 is Error! ".format(i))

# %%
print(df_sf.head())
# Out:
#                                     md5  Arithmetic_result  item_1  item_2  item_3  item_sum
# 0  0007d2d5b8edab9ed073d17ee5a29719.jpg                  0       0       0       0         0
# 1  000cd9c8584700deff0501f435c8a58b.jpg                  0       0       0       0         0
# 2  00180a4859798d6a363d7336efde531f.jpg                  0       0       0       0         0
# 3  001cd46d9b89095ccdf7a7d518cb9279.jpg                  0       0       0       0         0
# 4  0021fc2480706a742402eb29cac6ff80.jpg                  0       0       0       0         0

# %%
# 读入template_mine.xls，得到患者信息和医生的诊断结果
df_tempt = pd.read_excel(input_path+df_template_file, sheet_name='11806', sep='\t', index_col=None)

# %%
# df_tempt.sort_values(by='name',ascending=False,inplace=True)

# %%
df_tempt['md5'] = df_tempt['md5'] + '.jpg'

# %%
df_tempt.head()
# Out:
#    main_pid  姓名                                   md5  Doctor_standard  v3.2  doc check1  doc check sick_name sick_name-chuli                                    path
# 0  10374185  艾迪  980e27e19bac3595c979442bc3aeda17.jpg                0     0           0          0        健康              健康  R_788319b735bf5111b3e9e6eebc57df9f.jpg
# 1  10374185  艾迪  c377db0f41c6e4da4fcb005bd5461f68.jpg                0     0           0          0        健康              健康  L_daca7354df0a4ddff060993befc594bf.jpg
# 2  10376875  艾军  3c9e3895f69da41026f308c3e36854ca.jpg                0     0           0          0        健康              健康  R_190410cae8d911541a267e24cf0d99b2.jpg
# 3  10376875  艾军  f88efdef54cf4b7408aa68a89e160ea2.jpg                0     0           0          0        健康              健康  L_5bf00f2f255834e28d22dc31cf64e8f2.jpg
# 4  10374579  艾鑫  52b12a8c1428e4b464d5fed6099c3c9e.jpg                0     0           0          0      屈光不正               #  L_2f55506360af7b4a2dfea5f22d7fae09.jpg

# %%
# 校验df_sf和df_tempt的数据条目总数是否相等~
if df_sf.shape[0] == df_tempt.shape[0]:
    print('df_sf和df_tempt的数据条目总数相等！')
else:
    print('df_sf数据条目为{},df_tempt数据条目为{}'.format(df_sf.shape[0],df_tempt.shape[0]))
# Out:
# df_sf和df_tempt的数据条目总数相等！

# %%
# 合并df_sf表与tempt_mine表中的数据
df = pd.merge(df_tempt,df_sf[['md5','Arithmetic_result']],how='left',on='md5',sort=False)   #参数sort：是否根据”连接键“对合并后的数据进行排序，默认为True
df.head()
# Out:
#    main_pid  姓名                                   md5  Doctor_standard  v3.2  doc check1  doc check sick_name sick_name-chuli                                    path  Arithmetic_result
# 0  10374185  艾迪  980e27e19bac3595c979442bc3aeda17.jpg                0     0           0          0        健康              健康  R_788319b735bf5111b3e9e6eebc57df9f.jpg                  0
# 1  10374185  艾迪  c377db0f41c6e4da4fcb005bd5461f68.jpg                0     0           0          0        健康              健康  L_daca7354df0a4ddff060993befc594bf.jpg                  0
# 2  10376875  艾军  3c9e3895f69da41026f308c3e36854ca.jpg                0     0           0          0        健康              健康  R_190410cae8d911541a267e24cf0d99b2.jpg                  0
# 3  10376875  艾军  f88efdef54cf4b7408aa68a89e160ea2.jpg                0     0           0          0        健康              健康  L_5bf00f2f255834e28d22dc31cf64e8f2.jpg                  0
# 4  10374579  艾鑫  52b12a8c1428e4b464d5fed6099c3c9e.jpg                0     0           0          0      屈光不正               #  L_2f55506360af7b4a2dfea5f22d7fae09.jpg                  0

# %%
# df.rename(columns={'decison_last':'V3.4.1'},inplace=True)   # 根据每次算法的版本修改列名称

# %% [markdown]
# # Pandas按指定条件筛选行数据
# ## 同时满足A列值为0，B列值为1的所有行数据
# df[(df['Doctor_standard']==0) & (df['Arithmetic_result']==1)]
# <br>亦或
# <br>df.loc[(df['Doctor_standard']==0) & (df['Arithmetic_result']==1),:]
# ## 业务逻辑：真假以医生的诊断结果为准，阴阳以算法的计算结果为准，二者排列组合。
# <br>真阳性(TP)：医生诊断为阳性，算法判断为阳性；
# <br>假阳性(FP)：医生诊断为阴性，算法判断为阳性；（‘误诊’）
# <br>真阴性(TN)：医生诊断为阴性，算法判断为阴性；
# <br>假阴性(FN)：医生诊断为阳性，算法判断为阴性；（‘漏诊’）

# %%
#根据指定筛选条件对算法数据进行分类
df_TP = df[(df['Doctor_standard']==1) & (df['Arithmetic_result']==1)]   # 真阳性
df_FP = df[(df['Doctor_standard']==0) & (df['Arithmetic_result']==1)]   # 假阳性——误诊
df_TN = df[(df['Doctor_standard']==1) & (df['Arithmetic_result']==1)]   # 真阴性
df_FN = df[(df['Doctor_standard']==1) & (df['Arithmetic_result']==0)]   # 假阴性——漏诊
print(df_FN)   #验证结果
# Out:
#        main_pid     姓名                                   md5  Doctor_standard  v3.2  doc check1  doc check                    sick_name    sick_name-chuli                                    path  Arithmetic_result
# 10     10375726    安福民  183a08bfbacdd728ddf0d716cdba197f.jpg                1     0           1          1                 AMD年龄相关性黄斑变性       AMD年龄相关性黄斑变性  L_ed2a847911216a29855d8df7071f50f2.jpg                  0
# 150    10373374     卞强  63a4d049132f30020d52efab812cf6be.jpg                1     0           1          1                       其他未知异常             其他未知异常  L_113c28f8ae7392dcf22c9c314b216c57.jpg                  0
# 151    10373374     卞强  7cafdda6afdf14c8ee811f17ca349f4f.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_26838aa171c17ba54d5ffee25e1cb12f.jpg                  0
# 154    10377396    卜艳丽  1c276ca7b78280e0c81a18ddcd78fd1f.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_ebaf4449cc08aaa79d8cf21a7e2a6fc1.jpg                  0
# 155    10377396    卜艳丽  52705e91762d06df550129ac2b973fd6.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_4af658a79e7ed12b4d3fc22044f3cf6e.jpg                  0
# 201    10375768    曹凤娟  a51a9bbc7668b174e9b3204049279f5e.jpg                1     0           1          1                视网膜动脉硬化#视网膜出血            ##视网膜出血  L_c7f91d235d2a05030742dbd01fd9c67b.jpg                  0
# 269    10378035    曹秀花  e26ce51d25865de5ff637dd24e1cb250.jpg                1     1           1          1                       其他未知异常             其他未知异常  L_ace3026e1af30bf6a22988ebae3e1e74.jpg                  0
# 391    10373843    陈翠芳  56124aed2f19d41849307d3d2bb8e3a3.jpg                1     1           1          1          视网膜动脉硬化#其他未知异常#豹纹眼底         ##其他未知异常##  L_4eca19c63b3addda05b2a1c31641fdc7.jpg                  0
# 502    10376878    陈明朋  7da110f157d3ff2f7ed65456d73e444c.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_d6fe2f282ad80ecce53f1ba3154a2ffc.jpg                  0
# 570    10375235    陈先玲  7d40c7d2c4e6c02100763f1b0493b223.jpg                1     0           1          1                        视网膜出血              视网膜出血  R_0ff348debe870fa0cac1ab911a28c6a1.jpg                  0
# 572    10375235    陈先玲  c440c88f1cdcb2e21d2856898309213a.jpg                1     1           1          1                        视网膜出血              视网膜出血  L_650df707aba360d233caaece4629901f.jpg                  0
# 631    10378106    陈永华  fc93cb3c0ef962607b464dca214bf5a1.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_6c533ff478f51ec28297db6143fde8f1.jpg                  0
# 766    10377561    丛付柱  23909ae9b688b10f80c99095bb2e0271.jpg                1     0           1          1                 AMD年龄相关性黄斑变性       AMD年龄相关性黄斑变性  R_ecaa1892b04bdba3c816ca0322688161.jpg                  0
# 767    10377561    丛付柱  e1b63a70e2f3cc035c7e95f66c49172b.jpg                1     0           1          1                 AMD年龄相关性黄斑变性       AMD年龄相关性黄斑变性  R_5e3f1fc69c774706aca7328cace233f0.jpg                  0
# 774    10375617    丛秋香  c429fd9dd8aa3f5de99b8d3587d260fb.jpg                1     1           1          1                  屈光不正#其他未知异常           ##其他未知异常  R_c1bba723dbd981d9173f3e50f83462fb.jpg                  0
# 806    10373913    崔光英  6ed94579139ec97f77f1a7431bf8f7b3.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_189a5d264a6fb3e0c0bedbba7d90dcd2.jpg                  0
# 893    10376050    单连芳  82f7bba3b001b547feb89a6f8ebe5a79.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_3e678927d67bd070dde97aa8d0a2d23f.jpg                  0
# 896    10376050    单连芳  e2bc68f2235ce456b8463a9d44f0b0ce.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_8fa4e39272117c40b55603f7026abf2f.jpg                  0
# 914    10376231   澹台凡增  70924b9caa7a9679ffef98ad9f683d08.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_1444cdc7b2dd11138d604e28b3da136f.jpg                  0
# 919    10378306    党绍锡  2349649de9ac887e60eccaac848a0999.jpg                1     0           1          1                  其他未知异常#豹纹眼底           其他未知异常##  L_31d92cb43e869465254fdde17d740f7a.jpg                  0
# 973    10375070    丁方荣  107d2b1ecc4301af8765180dfa8792ba.jpg                1     0           1          1                           糖网                 糖网  R_4b927b8e72efb33344ec6c750d9c9647.jpg                  0
# 989    10378369    丁尚武  02e29cf41896382bc20e51a2b57dfdd0.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_fd593783c83796977ccba0eafaf6b809.jpg                  0
# 990    10378369    丁尚武  0b99ef6b2bb5a8a8d9a51c1e65bb239f.jpg                1     1           1          1                       其他未知异常             其他未知异常  L_d213f8fd43c70cd3b5da25e4ed86efe6.jpg                  0
# 1011   10375633    董冰冰  d5e5098943c0e7e9caac02321ee4d447.jpg                1     0           1          1                 AMD年龄相关性黄斑变性       AMD年龄相关性黄斑变性  L_194d4103e17c4ebe29e096a8faaf39d3.jpg                  0
# 1060   10377737    董清科  43fb581972ef92f1fe851e8609867958.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_53e783292ba236db3b705f3d2ebab40b.jpg                  0
# 1140   10378312    杜凤景  1dbb76847b89d56cfc629c817d10f078.jpg                1     1           1          1                       其他未知异常             其他未知异常  L_7f437483513c253aa121f8012fbb3def.jpg                  0
# 1347   10368949    方朝仲  ec101c3339432aa8126f1cb3fa2f4130.jpg                1     0           1          1                       其他未知异常             其他未知异常  L_579e63093b42aad1f923193bab816d87.jpg                  0
# 1794   10372801    巩传峰  0974ea68aeb447b7b78b5c41e8168e91.jpg                1     0           1          1          视网膜动脉硬化#其他未知异常#豹纹眼底         ##其他未知异常##  L_1006ef4e6d1bba774fe34a40389d1b3d.jpg                  0
# 1871   10375243    郭春兰  d1b765a67e6200a79667daaa005163e2.jpg                1     0           1          1                         黄斑前膜               黄斑前膜  R_786935523ada77dce76e550000d3b08e.jpg                  0
# 1872   10375243    郭春兰  fa8a992d88128023a9c48616eb00e0c0.jpg                1     0           1          1                         黄斑前膜               黄斑前膜  R_829b0b8822ea73e98606021990d23742.jpg                  0
# 1901   10372695    郭洪霞  8226e3e78102cf645730dbceabb2bdbe.jpg                1     0           1          1                视网膜动脉硬化#视网膜出血            ##视网膜出血  L_3243352a56cc2b0810cbad74d6cceb27.jpg                  0
# 2064   10378110    国秀清  3c9d6924e56e9125ea7d61a969aad89d.jpg                1     1           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_58e9a924f4c0bc14a6f98495ced9ec1c.jpg                  0
# 2212   10378291    郝志秀  777f368b6ad2452e17f609de8a4da2bf.jpg                1     1           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_68ba2695d9e9a1933a1627f6b678ba9b.jpg                  0
# 2213   10378291    郝志秀  b8d6c1ebc9fd2adb8118f04b23219950.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_420fbb38812bd73366e060b52270b354.jpg                  0
# 2246   10377871    何绍芬  f8572848a72cb10c86f9f06267b115eb.jpg                1     0           1          1                 可疑白内障#其他未知异常           ##其他未知异常  L_0670511d71848590db10cffe6be96816.jpg                  0
# 2358   10377242    候爱荣  b31341dc7f6c40dc875b3e9eca84ce5d.jpg                1     0           1          1                 视网膜动脉硬化#黄斑前膜             ##黄斑前膜  L_1c198196488de74cc2c4c4aa28376152.jpg                  0
# 2414   10377180    胡士国  6c38c7e14064df6c659c5a7db6b7ff41.jpg                1     1           1          1                       其他未知异常             其他未知异常  R_8e4d2b52a97e6c054f11d08da03e020b.jpg                  0
# 2441   10373308    胡亚忠  30d0069f0d9404e6f422c95e0215854b.jpg                1     0           1          1                       其他未知异常             其他未知异常  L_eda3074b7d8a9023825799cae90176b7.jpg                  0
# 2442   10373308    胡亚忠  884bb451038bd7e9f5afa04f3fa1ec76.jpg                1     0           1          1                       其他未知异常             其他未知异常  L_d6a83cfb721da745b66188463f5b7f02.jpg                  0
# 2443   10373308    胡亚忠  e3f3b5cc64e9f4f3b4a63250d01e687a.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_8e7e96e01d909ceeaebbe5226c85f4fa.jpg                  0
# 2526   10376358    黄丽影  35bc56ad5f7923f31075b921271d3960.jpg                1     0           1          1                       其他未知异常             其他未知异常  L_61422e14dafb86a6ea4e3bafedd9bc26.jpg                  0
# 2566   10374437     黄炜  b802bb8a0647857e1647cc014bff9d55.jpg                1     1           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_153b9ab968a10613c1a652453dcd109b.jpg                  0
# 2612   10376086    姬玉玲  5fed3cc0c4631426418c84df1a1f2191.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_a706caec04c32a7508a740b2cdb9e002.jpg                  0
# 2625   10374789    纪晓林  8dd28609c709617d78853e89d69c02ab.jpg                1     1           1          1                       其他未知异常             其他未知异常  R_f3c8f3ec5d23f4971b48c6c770486506.jpg                  0
# 2626   10374789    纪晓林  a31c22e28ee5c93742e197b4024f1b66.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_c93fd64945e6b75013bd235ed88dd4da.jpg                  0
# 2654   10373805    季香玲  1da0af7b81481bdbdfcbfb234b202605.jpg                1     1           1          1                       其他未知异常             其他未知异常  R_aa7234e8293219725aa4594bf8fe2bd4.jpg                  0
# 2708   10376317    贾学森  bf7aeaffe20abbf1780e1c34d08d950b.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_b2313f49e4a6954f84c7617925b14fb0.jpg                  0
# 2889   10376554    金伟峰  902ca7b4a58c978830a66a0b862cc5ca.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_6ce0dded12977738785560b0fbbe8373.jpg                  0
# 2890   10376554    金伟峰  a24a1de55249b17e32bf8e755c27dbb0.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_bae34bb75f062da2f533339b5992bb6b.jpg                  0
# 3015   10376257    孔祥涛  b95d2c7e5fba3cfac50c016594d7483d.jpg                1     1           1          1                       其他未知异常             其他未知异常  R_7f24e0da70fd44602d54f13d02008dad.jpg                  0
# 3078   10372682    李百忍  2f2a1c05bd60df77ac55fa2d9cc69541.jpg                1     0           1          1          视网膜动脉硬化#其他未知异常#豹纹眼底         ##其他未知异常##  L_c38f2f273fb19752d0168485d8550b59.jpg                  0
# 3145   10375623    李翠婷  3f8089ad20751eb6b44fd5da786c7e21.jpg                1     0           1          1                 AMD年龄相关性黄斑变性       AMD年龄相关性黄斑变性  R_14e12c3026e2806cc3e620d4c1e8d905.jpg                  0
# 3246   10373678    李桂芳  c924f7b2ec755b4bc4a2637d223f3550.jpg                1     0           1          1          视网膜动脉硬化#其他未知异常#豹纹眼底         ##其他未知异常##  R_19b9038930b7a8099787e31836df2e3c.jpg                  0
# 3282   10376816    李海瑞  3621bf0aaaefead7f9e26faf85759f05.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_ee4058126e1d8c546ed4d57a0386b8a9.jpg                  0
# 3329   10376029    李怀芝  6f4ab945580af71bb4aa4f305ed613b9.jpg                1     0           1          1                视网膜动脉硬化#视乳头水肿            ##视乳头水肿  L_31cf2baf9eaec14b75f2cb1c22c20b7c.jpg                  0
# 3331   10376029    李怀芝  91e1a068fae66cdbde5a20505ae06794.jpg                1     0           1          1                视网膜动脉硬化#视乳头水肿            ##视乳头水肿  L_7a296b72783b181ed11b3237f4c83978.jpg                  0
# 3369   10376081    李金美  f5c7f33441282a9245e705a55515974a.jpg                1     0           1          1       屈光不正#AMD年龄相关性黄斑变性#豹纹眼底   ##AMD年龄相关性黄斑变性##  R_d4400c060e35397a0705a38915b750a7.jpg                  0
# 3412   10378289    李来军  30e57c9a61b8804546f90b7b25e403e0.jpg                1     0           1          1          视网膜动脉硬化#屈光不正#玻璃体后脱离         ####玻璃体后脱离  R_1b8fc2ac8ce28d22bec63ebada9b89ea.jpg                  0
# 3413   10378289    李来军  700dff16c4e33803c3148815d1854ccf.jpg                1     0           1          1          视网膜动脉硬化#屈光不正#玻璃体后脱离         ####玻璃体后脱离  R_1a6a12cf2b3ff4029a03a0dbbbc2f6cc.jpg                  0
# 3475   10375614    李美颖  f41b78f5719a4c58ba486cfbffb69014.jpg                1     1           1          1                       其他未知异常             其他未知异常  L_aa0e5e1ce99ef41b4dd9defcccdd1d70.jpg                  0
# 3539   10376359    李清远  0d7e6eb3b543449d07ab8eea847ca830.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_e592c985e2d46df69bea70ec3872b80e.jpg                  0
# 3658   10374611    李万美  314821c0d4430459a7c308510ac5aab9.jpg                1     0           1          1                    高血压性视网膜病变          高血压性视网膜病变  R_9378d3970899fd88b204ccec96475bca.jpg                  0
# 3660   10374611    李万美  4bf2b634371691416fb0c9a13640b264.jpg                1     0           1          1                    高血压性视网膜病变          高血压性视网膜病变  R_94b72f074515c044aed68d009f41ed29.jpg                  0
# 3661   10374611    李万美  f7de8d682a59cfe04731d1f75aee6c7f.jpg                1     0           1          1                    高血压性视网膜病变          高血压性视网膜病变  R_4adeb41594aaf041b69816aff2428d73.jpg                  0
# 3743   10375685    李孝芹  5219a296e1d774f0a1f353ee1129a0f8.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_0fb758e2fac772e07e337313bab94d98.jpg                  0
# 3744   10375685    李孝芹  839f76c2835d53785c811a9d9c43c46c.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_3eb2d680a7201b971cea171b8eb22ae0.jpg                  0
# 3745   10375685    李孝芹  d2090b68e41f43c2f7d8fe72a2c98559.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_9ebc8caa1e97f24526ea26884e08e093.jpg                  0
# 4052   10377159    梁乃富  ee4348b6241f535cee7c18aec289bc1d.jpg                1     0           1          1                           糖网                 糖网  L_08a5338b9d35a35a825d21487c162104.jpg                  0
# 4077   10377183    梁秀芹  e93a37fbde693afabadf9d14b301eedb.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_09a9904d55ba380fb99b3362b8fa1a3d.jpg                  0
# 4184   10378333    刘保彬  6f4e6e8e14deffdedf8bdc44231f7a40.jpg                1     0           1          1                        玻璃体变性              玻璃体变性  L_9eb210f6205cdedcccc618742188580c.jpg                  0
# 4508   10373010    刘连涛  a9138437da0304d72939ff4b7c821fac.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_0934c9eb183478405553492f34e234d6.jpg                  0
# 4531   10376238    刘梅环  96f82a6411eeb1553463fc68562ec3f0.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_cc92bbed9ef5fae6f571fa8c28907bbb.jpg                  0
# 4533   10376238    刘梅环  c99a95c091f91b61f35e8bba4b23897a.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_cb7f5ae64402370e5a375613c3e5b7d6.jpg                  0
# 4691   10375979    刘先壮  8cad73ea75011b4de5fa82b7a393cf5f.jpg                1     1           1          1                       其他未知异常             其他未知异常  L_2c3565553e2b096dddcf2e26285b6074.jpg                  0
# 4788   10376982    刘艳丽  daa5cdd0ed4441ac10faaa0bc0f9fd02.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_2bf7489d86a0b32924ef2b50b49524b5.jpg                  0
# 4918   10375582    卢红雨  1b22eec00fc4b0005890aad124dcd81a.jpg                1     1           1          1                 AMD年龄相关性黄斑变性       AMD年龄相关性黄斑变性  L_6cafa39039615833ba10a79fc6ec5e98.jpg                  0
# 4919   10375582    卢红雨  4ecc086d9ca9ae16c95ee61694867d1a.jpg                1     1           1          1                 AMD年龄相关性黄斑变性       AMD年龄相关性黄斑变性  R_ac1103c1955eefb0f7674e9e92314877.jpg                  0
# 4949   10376285    鲁小学  ce27f9e3cd8dda85648fe84eec513266.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_875abd938e0c207752c72a759a729870.jpg                  0
# 5021   10374133    罗凤华  e9efae837ab6cfd63b3d0888214928d7.jpg                1     0           1          1                   玻璃体变性#豹纹眼底            玻璃体变性##  R_c4278b31d3fa636f564d7bd7f8cecec5.jpg                  0
# 5265   10377749    马新兰  2374375654c551838efa4395552ba7c1.jpg                1     1           1          1      视网膜动脉硬化#屈光不正#病理性近视#豹纹眼底        ####病理性近视##  R_64e6694eff27dc728acb2438695ae2b9.jpg                  0
# 5302   10377475    马玉芝  241a883aacb3cf80870f6dbdb18ce14b.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_3ff4adcda34885fb0aa1a0584ccfc7f2.jpg                  0
# 5319   10376199    马振莲  57c3fdc781f3b8695be28b8c652a2b13.jpg                1     0           1          1         视网膜动脉硬化#可疑白内障#其他未知异常         ####其他未知异常  L_3868020534fef2435116cc25ac1f1348.jpg                  0
# 5378   10378944    孟庆英  64f3cc199bed48e38ffd884a62c1e0d8.jpg                1     0           1          1                       其他未知异常             其他未知异常  L_dacbdca22b9aca881876d850778b7d3d.jpg                  0
# 5515   10373307    潘发兰  cc1d438244173d918a0c38af9d7154b7.jpg                1     1           1          1          视网膜动脉硬化#其他未知异常#豹纹眼底         ##其他未知异常##  L_4bdaf8ed787388a6d79faa4cb3bde213.jpg                  0
# 5516   10373307    潘发兰  df8f2701959ae1e9c74008734042a77d.jpg                1     1           1          1          视网膜动脉硬化#其他未知异常#豹纹眼底         ##其他未知异常##  R_ab15818d5acb954e0ac9d1dcbb489392.jpg                  0
# 5545   10375471     潘勇  41f00f50d2083397de742c5d22689514.jpg                1     0           1          1      视网膜动脉硬化#青光眼视神经损坏#其他未知异常         ####其他未知异常  R_bfaf981c1cffb003666f9d48c5b5cc30.jpg                  0
# 5612   10374329    彭秀红  ace4395b96259ecc851f0564c77c3ec4.jpg                1     0           1          1                    视网膜有髓神经纤维          视网膜有髓神经纤维  R_4bd559da33eb26c1c4694ed12a866559.jpg                  0
# 5637   10374911    戚新琴  1061f14e843cd33aa8a9df5a0fbc5a6d.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_a9979a36efba5fb51165a7494c115681.jpg                  0
# 5668   10376243    钱国余  092fc65a1cd4e0e8a14d9afb21b7c8a2.jpg                1     0           1          1                 视网膜动脉硬化#黄斑前膜             ##黄斑前膜  R_2895f1b069beece4ffd6d1de7815289d.jpg                  0
# 5677   10375506    钱永福  a521e9c5a4c2eb98066d16bce3e07a8c.jpg                1     0           1          1  视网膜动脉硬化#屈光不正#视网膜有髓神经纤维#豹纹眼底    ####视网膜有髓神经纤维##  L_e8fdae0247dea2db3f935b2c4f8217e8.jpg                  0
# 5756   10377928    渠景振  b02753160d039024b014f48971d2ac59.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_3e43e5b5162cc6bc26549becf1cef115.jpg                  0
# 5878   10376818    荣维国  1a08e84ed6ea34ec22334c072d5eeb5b.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_86b3ab3254aa5a6b71e8f6e86bc8aa8a.jpg                  0
# 5993   10375645    施金辛  38f58aca550d9d2da046e18f28689d0d.jpg                1     0           1          1                   糖网#视网膜动脉硬化               糖网##  R_43b2c6156ab40cc7d8d9ee51f6523ab6.jpg                  0
# 6093   10377723    史鹏健  5ccae9ed5a873efe1460bb277cf53906.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_d204e74c8962ef81c1676206c2470996.jpg                  0
# 6094   10377723    史鹏健  60e2a2ea3cef0226c986749242c7e82c.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_6e787ff9b258d43c6383a88f9c7b693f.jpg                  0
# 6117   10373301    史玉银  9440d2560b197e2151fb81c8cb5d9417.jpg                1     1           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_08fe51fb1786701d4d8ea8fb4373c171.jpg                  0
# 6118   10375525    史元英  a06fb45655d764cdc85570a5297d1c27.jpg                1     1           1          1      视网膜动脉硬化#屈光不正#病理性近视#豹纹眼底        ####病理性近视##  R_df933cf0bc26d3c0b115e3dbf4c9b060.jpg                  0
# 6164   10374585    宋德花  18dba25da7a2b8bac3a70ae6f264ae81.jpg                1     1           1          1       屈光不正#AMD年龄相关性黄斑变性#豹纹眼底   ##AMD年龄相关性黄斑变性##  R_a3a11fcb008fe1e2c9f2685107336f7c.jpg                  0
# 6176   10378191    宋国华  044607f328a4a32b62e429283cc20ad6.jpg                1     0           1          1                       其他未知异常             其他未知异常  L_d369af764d4c97dc265a11cd750da1a2.jpg                  0
# 6375   10373325    孙佃凤  fe93e6a7a43b7af6a2cbd5c3cc0f645a.jpg                1     1           1          1              屈光不正#病理性近视#豹纹眼底          ##病理性近视##  L_7cba4ca4d3b83211677db916f95c2ef1.jpg                  0
# 6538   10375816     孙添  3a9f93db5a2b41c9507a16c4ba0ea632.jpg                1     1           1          1                       其他未知异常             其他未知异常  R_d3836648353951fd079a8d65fb76fb05.jpg                  0
# 6573   10378331    孙欣荣  b982db6294a9f836b52b82de8db34e21.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_f6389d6bd5d1b1508514bd048f2062fb.jpg                  0
# 6658   10376230    索建民  a62c17279fb175b4555ae7b68a72a55b.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_8f961764ebf3bf8ba5a8b664e5c3fa35.jpg                  0
# 6696   10376915    谭亚丽  5d91ad2b01923e98c2df7d490d974959.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_669d3ed2896c4af78f5292ee38e21528.jpg                  0
# 6697   10376915    谭亚丽  736e228ed7dc3c1f7d6baf964b0ad465.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_c6930d18dcb77e8b6fabc2b7568bc926.jpg                  0
# 6698   10376915    谭亚丽  d115d7fab32323744edf0cc9bf5b6fd4.jpg                1     1           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_d2d6eb7f826e1e908a44f91ecd415ef0.jpg                  0
# 6718   10377109     唐峰  74a0751ce4c10ea6d83e14b57a7b1809.jpg                1     1           1          1                   视乳头水肿#豹纹眼底            视乳头水肿##  L_87d62c18b2f860268b7c3ec28eb565d4.jpg                  0
# 6767   10376138    田爱花  f7641d01f37c762b20f721a1ffe81589.jpg                1     0           1          1                       其他未知异常             其他未知异常  L_5c088f8aa8d7f58a942c8e987584fdae.jpg                  0
# 6776   10377024    田凤芝  28dc0dd52bcc9233f1668bdcb0b326e4.jpg                1     0           1          1          视网膜动脉硬化#其他未知异常#豹纹眼底         ##其他未知异常##  R_90b2ddc05e53fb9493d69fda95c32442.jpg                  0
# 6804   10372867    田茂胜  03fc707be447370547301e60379b6b01.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_b574a2e3fa3c67c0813feb5905d0d493.jpg                  0
# 6805   10372867    田茂胜  7f42375eac27ec2b35c6ee6536de3d04.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_b87865feadcb7f94b60f51395f7d99cb.jpg                  0
# 6905   10373337    万兰英  dbde68c0b9989eaebe3d514972a3450a.jpg                1     0           1          1                       其他未知异常             其他未知异常  L_1519d96fb72e6aec4feb4b86e4929493.jpg                  0
# 6953   10372698    王爱荣  e622d7c878632afa44168f8693c38396.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_0360a563a4a46c0f93ea29f0ecac0b94.jpg                  0
# 6984   10377314     王彬  9463aa7d206407956b930df1ccec7686.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_af97d5113f30fcbdd1c6c37e8ef3d2a5.jpg                  0
# 6985   10377314     王彬  c59c79db84a0a5aab0533fbec666a908.jpg                1     1           1          1                       其他未知异常             其他未知异常  L_19cc88afb69de03a1d2f1f0805dab242.jpg                  0
# 7021   10377776    王朝明  281cca937f82da60797cb11097e6ec48.jpg                1     1           1          1              屈光不正#病理性近视#豹纹眼底          ##病理性近视##  R_ed9ed31dd4647ddeb4e61a26a0067adb.jpg                  0
# 7023   10377776    王朝明  7e4f26bafd3b7f0b4d45558a522105bb.jpg                1     1           1          1              屈光不正#病理性近视#豹纹眼底          ##病理性近视##  R_679abe60f12290f6aad017419cda2c21.jpg                  0
# 7139   10375476     王飞  494171183b613aa03a546f1cd6c83148.jpg                1     1           1          1              青光眼视神经损坏#其他未知异常           ##其他未知异常  R_9ac479d1c16f1457b5287d04bcabb2c9.jpg                  0
# 7147   10376197    王凤兰  1a57a796fa734f7e498f4c8942a41a76.jpg                1     0           1          1           视网膜动脉硬化#黄斑前膜#可疑白内障           ##黄斑前膜##  R_5d05067e320771bad0e3dfd1a82c99b0.jpg                  0
# 7171   10378359     王刚  653d9326cdbf8dab1cfa9a41b0cd8453.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_f9d1993344f4b26991001783c2aa5e6b.jpg                  0
# 7172   10378359     王刚  eb9d9ef5145fbb41c8ed9c410a88656d.jpg                1     1           1          1                       其他未知异常             其他未知异常  L_232f0dc385fbe273836e6513614e3e3d.jpg                  0
# 7329   10375257    王建廷  9415184bddcc5f5d02af8b094a2e6d43.jpg                1     1           1          1         视网膜动脉硬化#AMD年龄相关性黄斑变性     ##AMD年龄相关性黄斑变性  L_f58e022ac07b27b2ea3c507fcf53427b.jpg                  0
# 7566   10376888    王其辰  c50107883b22614b00b0713d8b1d3833.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_8eae6d13cec576dc4c2d08bce5b5ddce.jpg                  0
# 7591   10377623    王庆坤  350062ed3a953c972808d419efd79816.jpg                1     0           1          1          视网膜动脉硬化#其他未知异常#豹纹眼底         ##其他未知异常##  R_5d6293ce70dd14faf58c646eb8cba540.jpg                  0
# 7679   10373195    王士栋  8b0455e5b6a6e81a187cda8ff35bad18.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_4b07180c1b576d82ab7a90b4720c7f7f.jpg                  0
# 7769   10377720    王素英  b4fe8743e1555cb895d919f0661114a5.jpg                1     1           1          1                           糖网                 糖网  L_e7818bab8d2efb6f8f07388d68235f1f.jpg                  0
# 7814   10375838    王文科  3085d0a46135cf70d8bdfb917bf01a96.jpg                1     1           1          1     视网膜动脉硬化#屈光不正#其他未知异常#豹纹眼底       ####其他未知异常##  L_995c7c82347fed9e0a18b63c1e9d2e43.jpg                  0
# 7848   10375002    王现宝  a6adda6eab79ed6c45ecbc1a3eea8d9d.jpg                1     1           1          1                 视网膜动脉硬化#静脉阻塞             ##静脉阻塞  L_bd0084c614b5fec7680debe79859b510.jpg                  0
# 7935   10375218    王秀芝  6d8592518d76abd786a3e35c4fc042c2.jpg                1     1           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_d717732391043be432ed7039fad0779c.jpg                  0
# 7968   10374744     王亚  f2d52ec3d7d183d0391ca8ed7c7f68f6.jpg                1     0           1          1                  屈光不正#其他未知异常           ##其他未知异常  L_b5d0407f5980d3ef57126948cba1b6b0.jpg                  0
# 7993   10377052    王艳方  d0191bdde23385bfb7f945e33bf2e274.jpg                1     0           1          1      视网膜动脉硬化#屈光不正#病理性近视#豹纹眼底        ####病理性近视##  L_a7ff7bfdf15a1032e1bd8b7098b61151.jpg                  0
# 8187   10375851    王振乡  e9cebd7bc0f0ccb0e017d6ba70e98577.jpg                1     1           1          1    视网膜动脉硬化#可疑白内障#其他未知异常#豹纹眼底       ####其他未知异常##  L_f2569c1da0ce7fbdc4456a34ea7ed983.jpg                  0
# 8266   10376551    魏宏峰  2d6ad9fd63048e48b036f8a1b7b7a38c.jpg                1     0           1          1                       其他未知异常             其他未知异常  L_71bce3016d98f654e1de0e9eb8fa8b56.jpg                  0
# 8430   10378033    吴继标  11a78d6ef3cc7bc56131dbc1393d6459.jpg                1     0           1          1     视网膜动脉硬化#屈光不正#其他未知异常#豹纹眼底       ####其他未知异常##  L_7c626c77f986a0a296d818ab7f44e361.jpg                  0
# 8437   10372839    吴来良  6107edb24496c4360841c185160006e5.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_4c9ec524ec75fc66bac6ff5fa62d612d.jpg                  0
# 8438   10372839    吴来良  c8a40210aca95d6ad4907b6309cb1737.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_9685a760737805550de56d8f9ac9b439.jpg                  0
# 8611   10377985    肖冠林  6975b2ff6c1fa48a6b3fa09a1eaa3976.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_f6df95276906766beef40d3903e1f347.jpg                  0
# 8816   10377049    徐恩存  870593f26b9e335bb939957904181a6a.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_9f7598028e47f3f4835799b2a49b9fb5.jpg                  0
# 8850   10374804    徐凤霞  cdd25e9b138c631486db6cca1ae20f54.jpg                1     0           1          1                       其他未知异常             其他未知异常  L_7e3655bdd46e2e0af7b7fc2d2eb780a1.jpg                  0
# 8867   10376531    徐桂平  3997da3766f9536a67b1b1eab85fe9ee.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_3ee044a45083dd091385ea92a2188aa2.jpg                  0
# 8868   10376531    徐桂平  cd1347ff4d69e892bfdd11e1c13a0f9d.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_c1ff8dcd6c5e8c5b66e7300371f541ca.jpg                  0
# 9012   10374831    徐永江  cebc40da178b7904029868fa161b3379.jpg                1     0           1          1                 视网膜动脉硬化#黄斑前膜             ##黄斑前膜  L_b6c46edce613e2b13bcd697e3755e217.jpg                  0
# 9022   10375268    徐玉兰  ff342535c099390e45bd6a15ef2ba689.jpg                1     1           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_23e2afafefdde5a3133d44fbe9c380c9.jpg                  0
# 9078   10373840  许海芸代查  ae45c3049c53a149be6f3d188f75bc3c.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_8ba1891660e2ae201a2187a6a906ca58.jpg                  0
# 9126   10378079    许苏云  dd7e156673bb69f9e2c14415f0964f99.jpg                1     0           1          1                  其他未知异常#豹纹眼底           其他未知异常##  R_86ce418ad52d737b0411e9883eeccb6c.jpg                  0
# 9207   10375643    闫常坤  72741951dca5e2aec2c9208d00eb9038.jpg                1     1           1          1                       其他未知异常             其他未知异常  L_2a84024ba0d5bfc3679f3660b921de6a.jpg                  0
# 9320   10378039    杨凤玲  6e223a4efc912365f1c487f62e3245a5.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_5505fc0309b3af831b748fe5f1e35955.jpg                  0
# 9321   10378039    杨凤玲  f258c73f3d682187237658d6eda34cd6.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_c79d63e57d5ee127550927af7fc2a14f.jpg                  0
# 9353   10375621    杨海青  d158c55db47a535c1ff31ec52029f950.jpg                1     0           1          1               视网膜有髓神经纤维#豹纹眼底        视网膜有髓神经纤维##  L_22a5e13ac825d24f26856f8e31704ec3.jpg                  0
# 9480   10374522    杨素珍  c5eb4ff378227390a31beb28d22cc24c.jpg                1     0           1          1                视网膜动脉硬化#视网膜出血            ##视网膜出血  L_8851e19c731a91d907a2a303c2f34bf8.jpg                  0
# 9564   10374787    杨玉平  f0df79c5852e22dc3e24ade1125f3706.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_0bee2bb971f27ec759fd1b07325e7b12.jpg                  0
# 9593   10376032    姚海莲  34f24fbb6e4ab9134006c6879de8771f.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_c920dddca5793e1a028974b040b969f6.jpg                  0
# 9594   10376032    姚海莲  487a849f19c787680fd4bc98690998b1.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_81568216289960b68bc067de5b03b0b0.jpg                  0
# 9595   10376032    姚海莲  b05f4e32dcc41f85b1ad34a2c4ebefc8.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_fd752fa28d25324d10c679770f8e2701.jpg                  0
# 9601   10373728    姚念金  fb9dc9f8930d34ef2ff4535dead3b52c.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_1aba601e889e9ae00e20aea2db2a44af.jpg                  0
# 9608   10374528    姚清芹  48f7acc49ff45e8863bc4f8b68aedc97.jpg                1     0           1          1                 视网膜动脉硬化#黄斑前膜             ##黄斑前膜  L_e369651bf16aab4d9a6f0d7be7048742.jpg                  0
# 9814   10375494    于明芝  4917db5ab2d0b6a8c036420e49c3fce0.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_80b7eb23d2cc4c42c82e832ec18da711.jpg                  0
# 9900   10375557    于赵平  2c28732eb4ccf6ab20371535d9b30dd3.jpg                1     0           1          1                 AMD年龄相关性黄斑变性       AMD年龄相关性黄斑变性  L_713ab77c039c17be4fe1fbf7e75806c8.jpg                  0
# 10050  10374961    张爱英  f5921fb6497e902d645267d6a68c702f.jpg                1     0           1          1                       其他未知异常             其他未知异常  L_5c66ee9f133e66773d1234445456e473.jpg                  0
# 10096  10377646    张春华  0a950805bc3717358a44461484563ce7.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_62ae44d84045d5fad8386e599d6665a8.jpg                  0
# 10097  10377646    张春华  b4ef4b06c504d541c9068eb99b760bb8.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_b835228457223aafcc65de81df855089.jpg                  0
# 10116  10373345    张翠玲  03891e40ef1fad895b2e5ec9b68e35cc.jpg                1     1           1          1                           糖网                 糖网  L_926d2b6faa69e030f79910877eaeec3d.jpg                  0
# 10126  10378296    张德莲  6698ba45c7c451d4c321cd1ec9837a7d.jpg                1     1           1          1                       其他未知异常             其他未知异常  L_ae9493948b2e5955e4491823793ee101.jpg                  0
# 10167  10376521    张风梅  84e109eb90851f2ace62458889acccf2.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_70f389c832f5e8ae98d978977ca8d75d.jpg                  0
# 10288  10375062    张会学  b085aa17e6345a639209764b651e0c6e.jpg                1     0           1          1                 AMD年龄相关性黄斑变性       AMD年龄相关性黄斑变性  R_b3f5b0b7cffff18237369b8a06380ad1.jpg                  0
# 10306  10375128    张继义  9b1ffaaf29761e067f23433a74ba4d56.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_0de434dccc1549c49ec01b778b706768.jpg                  0
# 10394  10377829    张兰春  4dd3f5bdeb1dccd7dd5a9a2a480469f2.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_27fe90dc7f204a64477b35afb1550105.jpg                  0
# 10573  10376849    张三妮  060a2679f50a329b9f11c493d327c7db.jpg                1     0           1          1                 视网膜动脉硬化#黄斑前膜             ##黄斑前膜  L_e803d6eeb22d1d3fe1dba9ea84af2a39.jpg                  0
# 10612  10375929    张书林  3fdfacb7a56fa2691f126915ee610ae4.jpg                1     1           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_cbe5bf14625f5e72e88ac23f73e31ac4.jpg                  0
# 10650  10375817    张同元  9f1066f8f0b233ec20bce098eb80f434.jpg                1     0           1          1                    高血压性视网膜病变          高血压性视网膜病变  R_c2b96eddb80000d34fd753ba4d28758e.jpg                  0
# 10743  10373896    张兴光  ac469d33995310cfc4e441cfc9681ae3.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_7850e92c6ed37741a0fb0c6eb98e9ed0.jpg                  0
# 10762  10374124    张秀娟  6627e43d35c5b93d600b12a79fe38522.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_e196b1dfd1a683b83e5ad3cf07403a28.jpg                  0
# 10824  10376014    张亚洲  7f52d5555a8bb25092000c26dc3c0198.jpg                1     1           1          1                    视网膜有髓神经纤维          视网膜有髓神经纤维  L_6c7ec214f5b4170771367964c10eb351.jpg                  0
# 10875  10377036    张义松  22afb57b7a8721617b6ad0604b06f15f.jpg                1     0           1          1                       其他未知异常             其他未知异常  L_7527452fd2279426b57bf5b8dbcbbe3c.jpg                  0
# 10894  10376202    张永良  3ac0383dec7911338b11d78ac44f6652.jpg                1     0           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  L_9f9dda54b563cc4f341a0b591b8d3704.jpg                  0
# 10906  10375888    张有绪  e5ef8c25063cedec33d8ba9761f2dfee.jpg                1     0           1          1                 视网膜动脉硬化#黄斑前膜             ##黄斑前膜  R_469dcc192bc2ffdd8a186ac261e48d22.jpg                  0
# 10968  10376556    张韵兰  04d4271224c649a07ff9c1b03c8bd079.jpg                1     0           1          1          视网膜动脉硬化#其他未知异常#豹纹眼底         ##其他未知异常##  L_b266fe656113551b29e205fe25f0b85e.jpg                  0
# 11017  10375754    张宗设  c83406400bc3f00ecba17fdd44deb12b.jpg                1     0           1          1                  屈光不正#其他未知异常           ##其他未知异常  L_06375089208d58641deda49341c590b5.jpg                  0
# 11042  10374179     章艳  f816221cfdf669ad7012793d552c62c9.jpg                1     1           1          1               视网膜动脉硬化#其他未知异常           ##其他未知异常  R_574b94532311c8dd9884f1d3dd55fe94.jpg                  0
# 11056  10374240    赵伯玲  0ab4c2e26ec83a95d90055890475fa8e.jpg                1     0           1          1                    视网膜有髓神经纤维          视网膜有髓神经纤维  R_aa6112333ae90f637cedd315b926665a.jpg                  0
# 11057  10374240    赵伯玲  e22ce204e92af888272704710ece9a2d.jpg                1     0           1          1                    视网膜有髓神经纤维          视网膜有髓神经纤维  R_8eec58e44753d855a122b50ff2fef69e.jpg                  0
# 11070  10373286    赵翠玲  838af01624246532b77604f22e5ec575.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_4155a2f987539cbb1b8bdb6d2ae62c27.jpg                  0
# 11211  10377738    赵圣花  532847f10e430388e318421b976974db.jpg                1     0           1          1      高血压性视网膜病变#视网膜动脉硬化#视网膜出血  高血压性视网膜病变###视网膜出血  L_ba778491af3c7dc44747d85035295d7d.jpg                  0
# 11519  10376514    周国强  0be0169ad3da80d20a7ce61d555c7ceb.jpg                1     0           1          1                       其他未知异常             其他未知异常  R_faa9fef548ed7c66da2a959e3e5440e0.jpg                  0
# 11560  10378205    周瑞霞  65fa572a43e3666b82b63f2009554623.jpg                1     1           1          1                 AMD年龄相关性黄斑变性       AMD年龄相关性黄斑变性  R_b3422488a655f9c2d97bd5d60b052935.jpg                  0
# 11737  10374701    祝一宾  092f5978af4a876e885c3955659ced1f.jpg                1     0           1          1                  屈光不正#其他未知异常           ##其他未知异常  L_2f6dfb6ef293fb0860cfe426e778e760.jpg                  0
# 11748  10377822    宗爱菊  3f1825d519a7cbea924860bf5c31efcc.jpg                1     0           1          1                       其他未知异常             其他未知异常  L_dcabe2298a8f26bb1505b8245c4b5205.jpg                  0

# %%
print("{}张假阳性图片数据".format(len(df_FP)))
# Out:
# 2306张假阳性图片数据

# %%
output_path =  r'/Users/edz/Documents/My-work/Daily_work/算法结果统计/mine/导出Result'
output_file = r'/df_V3.4.1版本_11806.xlsx'   
writer = pd.ExcelWriter(output_path+output_file)
df_FP.to_excel(writer,sheet_name='df_FP误诊',index=None)   #  “假阳性——误诊“
df_FN.to_excel(writer,sheet_name='df_FN漏诊',index=None)    # “假阴性——漏诊”
writer.save()

# %% [markdown]
# # Part02 算法“误诊”的数据由两部分组成：
# （1）图片确实存在明显病灶，尽管医生诊断患者为阴性，但算法是基于”病灶正确标注“设计的，因此算法的判断结果——正确；<br>
# （2）图片的病灶不确定，由于医生诊断患者为阴性，此时仍以医生的结果为准，认为算法的病灶标注错误，因此算法的判断结果——错误；
# 接下来，人工审核环节的主要工作就是校核找出（1）部分的”假阳性“算法数据。
# <br>筛查标准列”Screening_standard“=修改过的——医生诊断结果列”Doctor_standard“（修改”假阳性“数据中图片存在明显病灶的医生诊断结果数据为”阳性“）
# ## 根据筛选出的”假阳“图片名称，寻找对应的图片，并将其copy到指定文件夹下

# %%
df_FP.reset_index(drop=True,inplace=True)   # 重置索引
df_FN.reset_index(drop=True,inplace=True)   # 重置索引

# %%
df_FP.head()
# Out:
#    main_pid   姓名                                   md5  Doctor_standard  v3.2  doc check1  doc check sick_name sick_name-chuli                                    path  Arithmetic_result
# 0  10377019   安杰  ae92fc91dcaf43cab1336e3696e74f8d.jpg                0     1           1          1      屈光不正               #  R_8293130e39be38054931692bee474a76.jpg                  1
# 1  10372947  安苏苏  98b2f0ab20e7bfe932ad57350dbff2e2.jpg                0     1           0          0        健康              健康  L_cdd254a2879dd9241799802dfd7617d8.jpg                  1
# 2  10376158  安晓静  4cc5325a6323b3e39f666940b896c5b1.jpg                0     1           1          1        健康              健康  R_2e27025073d9c57ccd2ca2bdd885fe92.jpg                  1
# 3  10376158  安晓静  528e7e0179c69b3892ca71c5c6e9398c.jpg                0     0           0          0        健康              健康  L_db50fbaff91a309584f6f5c8a9c45f78.jpg                  1
# 4  10378077   安秀  5852d62dfdfd94ab0b46b1303c8bd5be.jpg                0     1           0          0        健康              健康    171a5cbb38c46872a95d919d8ede491b.jpg                  1

# %%
df_FN.head()
# Out:
#    main_pid   姓名                                   md5  Doctor_standard  v3.2  doc check1  doc check       sick_name sick_name-chuli                                    path  Arithmetic_result
# 0  10375726  安福民  183a08bfbacdd728ddf0d716cdba197f.jpg                1     0           1          1    AMD年龄相关性黄斑变性    AMD年龄相关性黄斑变性  L_ed2a847911216a29855d8df7071f50f2.jpg                  0
# 1  10373374   卞强  63a4d049132f30020d52efab812cf6be.jpg                1     0           1          1          其他未知异常          其他未知异常  L_113c28f8ae7392dcf22c9c314b216c57.jpg                  0
# 2  10373374   卞强  7cafdda6afdf14c8ee811f17ca349f4f.jpg                1     0           1          1          其他未知异常          其他未知异常  R_26838aa171c17ba54d5ffee25e1cb12f.jpg                  0
# 3  10377396  卜艳丽  1c276ca7b78280e0c81a18ddcd78fd1f.jpg                1     0           1          1  视网膜动脉硬化#其他未知异常        ##其他未知异常  R_ebaf4449cc08aaa79d8cf21a7e2a6fc1.jpg                  0
# 4  10377396  卜艳丽  52705e91762d06df550129ac2b973fd6.jpg                1     0           1          1  视网膜动脉硬化#其他未知异常        ##其他未知异常  L_4af658a79e7ed12b4d3fc22044f3cf6e.jpg                  0

# %%
select_list_FP = []   # 定义存放df_FP图片名称的列表
for i in range(len(df_FP['md5'])):
    select_list_FP.append(df_FP.at[i,'md5'])

select_list_FN = []   # 定义存放df_FN图片名称的列表
for i in range(len(df_FN['md5'])):
    select_list_FN.append(df_FN.at[i,'md5'])

# %%
copy_image_path_FN = r'/Users/edz/Documents/My-work/Daily_work/算法结果统计/mine/导出Result/FN_image_11806'
copy_image_path_FP = r'/Users/edz/Documents/My-work/Daily_work/算法结果统计/mine/导出Result/FP_image_11806'
Label_image_path = r'/Users/edz/Documents/My-work/Daily_work/算法结果统计/v3.4.1/11806/result_11806'
n = 0  # 统计数目
m = 0
for maindir, subdir, file_name_list in os.walk(Label_image_path):
#     print(maindir)
    for filename in file_name_list:
        if filename.endswith('.jpg' or '.JPG'):
            if filename in select_list_FP:
                olddir = os.path.join(maindir,filename)
#                 print(filename,'在目标文件夹中')
                copy_filedir_FP = os.path.join(copy_image_path_FP,filename)   # copy_filedir定义了copy_FP图片的目标文件夹
                n += 1
                shutil.copy(olddir,copy_filedir_FP)   # 执行Copy图片的操作
            elif filename in select_list_FN:
                olddir = os.path.join(maindir,filename)
#                 print(filename,'在目标文件夹中')
                copy_filedir_FN = os.path.join(copy_image_path_FN,filename)   # copy_filedir定义了copy_FN图片的目标文件夹
                m += 1
                shutil.copy(olddir,copy_filedir_FN)   # 执行Copy图片的操作
            else:
                pass

print('FP符合的文件数',n)  
print('FN符合的文件数',m)
# Out:
# FP符合的文件数 2306
# FN符合的文件数 187

# %% [markdown]
# ## Part03：对于”假阳性图片“：即：医生诊断为阴性，但算法标注为”有病灶（即：阳性）“
# 基于人工审核过，过滤掉”医生诊断为阴性，但图像标注确实是有病灶的图片“，其余的算作算法标注病灶错误。

# %%
# 将筛选出的中文件夹的图片文件的文件名提取出来，并且转化为”图片名称的list“
input_doctor_modified_path = r'/Users/edz/Documents/My-work/Daily_work/算法结果统计/mine/导入Data/算法正确-820'
doctor_modified_list = []
for maindir, subdir,file_name_list in os.walk(input_doctor_modified_path):
    for filename in file_name_list:
        if filename.endswith('.jpg' or '.JPG'):
            doctor_modified_list.append(filename)
print(len(doctor_modified_list),'doctor诊断结果的column中需要修改为阳性的行数据总条数！')
# Out:
# 820 doctor诊断结果的column中需要修改为阳性的行数据总条数！

# %%
# 将原”Doctor_standard“列复制给”筛查标准列“，此处即：”Screening_standard“列
df.insert(df.columns.get_loc('Doctor_standard')+1,'Screening_standard',value=df['Doctor_standard'])   # 指定位置插入插入指定列，同时用指定的某列的值填充对应项
print(df.head())   #验证插入列是否符合要求
# Out:
#    main_pid  姓名                                   md5  Doctor_standard  Screening_standard  v3.2  doc check1  doc check sick_name sick_name-chuli                                    path  Arithmetic_result
# 0  10374185  艾迪  980e27e19bac3595c979442bc3aeda17.jpg                0                   0     0           0          0        健康              健康  R_788319b735bf5111b3e9e6eebc57df9f.jpg                  0
# 1  10374185  艾迪  c377db0f41c6e4da4fcb005bd5461f68.jpg                0                   0     0           0          0        健康              健康  L_daca7354df0a4ddff060993befc594bf.jpg                  0
# 2  10376875  艾军  3c9e3895f69da41026f308c3e36854ca.jpg                0                   0     0           0          0        健康              健康  R_190410cae8d911541a267e24cf0d99b2.jpg                  0
# 3  10376875  艾军  f88efdef54cf4b7408aa68a89e160ea2.jpg                0                   0     0           0          0        健康              健康  L_5bf00f2f255834e28d22dc31cf64e8f2.jpg                  0
# 4  10374579  艾鑫  52b12a8c1428e4b464d5fed6099c3c9e.jpg                0                   0     0           0          0      屈光不正               #  L_2f55506360af7b4a2dfea5f22d7fae09.jpg                  0

# %%
# 修改template_mine.xls中”Doctor_standard“为”0“（即：人工审核后52张医生诊段结果为阴性，但算法标注图像确实存在病灶的图片，此时将医生诊断结果”doc“列的结果修改为阳性，作为新的筛查标准）
m = 0
for i in range(len(df['md5'])):
    if df.at[i,'md5'] in doctor_modified_list:
        #print(df_template_gai.at[i,'doc'])
        df.at[i,'Screening_standard'] = 1   # 修改'Screening_standard'列
        m += 1
    else:
        pass
print('"Screening_standard"列修改——基于doctor诊断结果列”Doctor_standard“中共计{}条数据需修改为阳性（即：1）~'.format(m))
# Out:
# "Screening_standard"列修改——基于doctor诊断结果列”Doctor_standard“中共计820条数据需修改为阳性（即：1）~

# %%
# 直接筛选出'Doctor_standard','Screening_standard'两列值不相等的行数据的DataFrame,# 验证修改成功
a = df.loc[df['Doctor_standard'] != df['Screening_standard'],['Doctor_standard','Screening_standard']]
print(len(a))
# Out:
# 820

# %% [markdown]
# ## 输出最终的结果汇总表——template_last_11806.xlsx
# ### 需要根据每次算法的版本号——修改columns列的名称

# %%
# Out:
#    main_pid  姓名                                   md5  Doctor_standard_V3.4.1  Screening_standard_V3.4.1  v3.2  doc check1  doc check sick_name sick_name-chuli                                    path  Arithmetic_result
# 0  10374185  艾迪  980e27e19bac3595c979442bc3aeda17.jpg                       0                          0     0           0          0        健康              健康  R_788319b735bf5111b3e9e6eebc57df9f.jpg                  0
# 1  10374185  艾迪  c377db0f41c6e4da4fcb005bd5461f68.jpg                       0                          0     0           0          0        健康              健康  L_daca7354df0a4ddff060993befc594bf.jpg                  0
# 2  10376875  艾军  3c9e3895f69da41026f308c3e36854ca.jpg                       0                          0     0           0          0        健康              健康  R_190410cae8d911541a267e24cf0d99b2.jpg                  0
# 3  10376875  艾军  f88efdef54cf4b7408aa68a89e160ea2.jpg                       0                          0     0           0          0        健康              健康  L_5bf00f2f255834e28d22dc31cf64e8f2.jpg                  0
# 4  10374579  艾鑫  52b12a8c1428e4b464d5fed6099c3c9e.jpg                       0                          0     0           0          0      屈光不正               #  L_2f55506360af7b4a2dfea5f22d7fae09.jpg                  0

# %%
template_last_output_path = r'/Users/edz/Documents/My-work/Daily_work/算法结果统计/mine/导出Result'
template_last_file = r'/template_last_11806.xlsx'
writer1 = pd.ExcelWriter(template_last_output_path + template_last_file)
df_copy.to_excel(writer1,sheet_name='V3.4.1版本',index=None)
writer1.save()

# %%
df.head()
# Out:
#    main_pid  姓名                                   md5  Doctor_standard_V3.4.1  Screening_standard_V3.4.1  v3.2  doc check1  doc check sick_name sick_name-chuli                                    path  Arithmetic_result
# 0  10374185  艾迪  980e27e19bac3595c979442bc3aeda17.jpg                       0                          0     0           0          0        健康              健康  R_788319b735bf5111b3e9e6eebc57df9f.jpg                  0
# 1  10374185  艾迪  c377db0f41c6e4da4fcb005bd5461f68.jpg                       0                          0     0           0          0        健康              健康  L_daca7354df0a4ddff060993befc594bf.jpg                  0
# 2  10376875  艾军  3c9e3895f69da41026f308c3e36854ca.jpg                       0                          0     0           0          0        健康              健康  R_190410cae8d911541a267e24cf0d99b2.jpg                  0
# 3  10376875  艾军  f88efdef54cf4b7408aa68a89e160ea2.jpg                       0                          0     0           0          0        健康              健康  L_5bf00f2f255834e28d22dc31cf64e8f2.jpg                  0
# 4  10374579  艾鑫  52b12a8c1428e4b464d5fed6099c3c9e.jpg                       0                          0     0           0          0      屈光不正               #  L_2f55506360af7b4a2dfea5f22d7fae09.jpg                  0

# %% [markdown]
# ## Part04 输出符合要求的统计表
# 基于“图片”维度和“患者”两个类别：
# <br>分别比较、统计:
# <br>(a)算法结果“Arithmetic_result”与医生诊断结果“Doctor_standard”的不同标签的样本数，以及“敏感性”、“特异性”和“准确性”；
# <br>(a)算法结果“Arithmetic_result”与筛查标准结果“Screening_standard”的不同标签的样本数，以及“敏感性”、“特异性”和“准确性”；

# %% [markdown]
# ## (1) 图片维度

# %%
Table_image = pd.DataFrame(columns=['属性_class','诊断标准_count','筛查标准_count'])

# %% [markdown]
# ### “敏感性”、“特异性”和“准确性”的计算公式如下：
# <br>(1)敏感性：TP/(TP+FN)
# <br>(2)特异性：TN/(TN+FP)
# <br>(3)准确性：

# %%
# 计算 “敏感性”、“特异性”和“准确性”
def statistics_fun(dfname_TP,dfname_FP,dfname_TN,dfname_FN):
    Sensibility = round((dfname_TP.shape[0] / (dfname_TP.shape[0] + dfname_FN.shape[0])),4)
    Specificity = round((dfname_TN.shape[0] / (dfname_TN.shape[0] + dfname_FP.shape[0])),4)
    Accuracy = round(((dfname_TP.shape[0] + dfname_TN.shape[0]) / (dfname_TP.shape[0]+dfname_FP.shape[0] + dfname_TN.shape[0] + dfname_FN.shape[0])),4)
    print("Sensibility:{}, Specificity:{}, Accuracy:{}".format(Sensibility, Specificity, Accuracy))
    return Sensibility, Specificity, Accuracy

# %%
print(df_TP.shape[0],df_FP.shape[0],df_TN.shape[0],df_FN.shape[0])
# Out:
# 343 2306 343 187

# %%
def classification_stantistics_fun(df_item):
    #根据指定筛选条件对算法数据进行分类——诊断标准
    df_item_TP = df_item[(df_item['Doctor_standard']==1) & (df_item['Arithmetic_result']==1)]   # 真阳性
    df_item_FP = df_item[(df_item['Doctor_standard']==0) & (df_item['Arithmetic_result']==1)]   # 假阳性——误诊
    df_item_TN = df_item[(df_item['Doctor_standard']==0) & (df_item['Arithmetic_result']==0)]   # 真阴性
    df_item_FN = df_item[(df_item['Doctor_standard']==1) & (df_item['Arithmetic_result']==0)]   # 假阴性——漏诊
    print("诊断标准：")
    print("TP:{}, FP:{}, TN:{}, FN:{}".format(df_item_TP.shape[0],df_item_FP.shape[0],df_item_TN.shape[0],df_item_FN.shape[0]))   #验证结果
    
    Sensibility = round((df_item_TP.shape[0] / (df_item_TP.shape[0] + df_item_FN.shape[0])),4)
    Specificity = round((df_item_TN.shape[0] / (df_item_TN.shape[0] + df_item_FP.shape[0])),4)
    Accuracy = round(((df_item_TP.shape[0] + df_item_TN.shape[0]) / (df_item_TP.shape[0]+df_item_FP.shape[0] + df_item_TN.shape[0] + df_item_FN.shape[0])),4)
    print("Sensibility:{}, Specificity:{}, Accuracy:{}".format(Sensibility, Specificity, Accuracy))
#     return Sensibility, Specificity, Accuracy
    #     statistics_fun(df_item_TP,df_item_FP,df_item_TN,df_item_FN)   # 调用函数——计算Sensibility, Specificity, Accuracy
    
    #根据指定筛选条件对算法数据进行分类——筛查标准
    df_item_sc_TP = df_item[(df_item['Screening_standard']==1) & (df_item['Arithmetic_result']==1)]   # 真阳性
    df_item_sc_FP = df_item[(df_item['Screening_standard']==0) & (df_item['Arithmetic_result']==1)]   # 假阳性——误诊
    df_item_sc_TN = df_item[(df_item['Screening_standard']==0) & (df_item['Arithmetic_result']==0)]   # 真阴性
    df_item_sc_FN = df_item[(df_item['Screening_standard']==1) & (df_item['Arithmetic_result']==0)]   # 假阴性——漏诊
    print("筛查标准：")
    print("TP:{}, FP:{}, TN:{}, FN:{}".format(df_item_sc_TP.shape[0],df_item_sc_FP.shape[0],
                                              df_item_sc_TN.shape[0],df_item_sc_FN.shape[0]))   #验证结果
    
    Sensibility_sc = round((df_item_sc_TP.shape[0] / (df_item_sc_TP.shape[0] + df_item_sc_FN.shape[0])),4)
    Specificity_sc = round((df_item_sc_TN.shape[0] / (df_item_sc_TN.shape[0] + df_item_sc_FP.shape[0])),4)
    Accuracy_sc = round(((df_item_sc_TP.shape[0] + df_item_sc_TN.shape[0]) / (df_item_sc_TP.shape[0]+
                        df_item_sc_FP.shape[0] + df_item_sc_TN.shape[0] + df_item_sc_FN.shape[0])),4)
    print("Sensibility:{}, Specificity:{}, Accuracy:{}".format(Sensibility_sc, Specificity_sc, Accuracy_sc))
#     return Sensibility_sc, Specificity_sc, Accuracy_sc
#     statistics_fun(df_item_sc_TP,df_item_sc_FP,df_item_sc_TN,df_item_sc_FN)   # 调用函数——计算Sensibility, Specificity, Accuracy
    
#     return df_item_TP,df_item_FP,df_item_TN,df_item_FN,df_item_sc_TP,df_item_sc_FP,df_item_sc_TN,df_item_sc_FN
    
    Table_item = pd.DataFrame(columns=['属性_class','诊断标准_count','筛查标准_count'])
    Table_image['属性_class'] = ['TP','FP','TN','FN','敏感性','特异性','准确性']   # 填充“属性_class”
    Table_image['诊断标准_count'] = [df_item_TP.shape[0],df_item_FP.shape[0],df_item_TN.shape[0],df_item_FN.shape[0],
                                   str(Sensibility), str(Specificity), str(Accuracy)]
    Table_image['筛查标准_count'] = [df_item_sc_TP.shape[0],df_item_sc_FP.shape[0],df_item_sc_TN.shape[0],
                                   df_item_sc_FN.shape[0],str(Sensibility_sc), str(Specificity_sc), str(Accuracy_sc)]
    
    return Table_image

# %%
df.rename(columns={'Doctor_standard_V3.4.1':'Doctor_standard',
                        'Screening_standard_V3.4.1':'Screening_standard'},inplace=True)
df.head()
# Out:
#    main_pid  姓名                                   md5  Doctor_standard  Screening_standard  v3.2  doc check1  doc check sick_name sick_name-chuli                                    path  Arithmetic_result
# 0  10374185  艾迪  980e27e19bac3595c979442bc3aeda17.jpg                0                   0     0           0          0        健康              健康  R_788319b735bf5111b3e9e6eebc57df9f.jpg                  0
# 1  10374185  艾迪  c377db0f41c6e4da4fcb005bd5461f68.jpg                0                   0     0           0          0        健康              健康  L_daca7354df0a4ddff060993befc594bf.jpg                  0
# 2  10376875  艾军  3c9e3895f69da41026f308c3e36854ca.jpg                0                   0     0           0          0        健康              健康  R_190410cae8d911541a267e24cf0d99b2.jpg                  0
# 3  10376875  艾军  f88efdef54cf4b7408aa68a89e160ea2.jpg                0                   0     0           0          0        健康              健康  L_5bf00f2f255834e28d22dc31cf64e8f2.jpg                  0
# 4  10374579  艾鑫  52b12a8c1428e4b464d5fed6099c3c9e.jpg                0                   0     0           0          0      屈光不正               #  L_2f55506360af7b4a2dfea5f22d7fae09.jpg                  0

# %%
print('V3.4.1——图片维度：(图片共计：{}张)'.format(len(df)))
classification_stantistics_fun(df)
# Out:
# V3.4.1——图片维度：(图片共计：11806张)
# 诊断标准：
# TP:343, FP:2306, TN:8970, FN:187
# Sensibility:0.6472, Specificity:0.7955, Accuracy:0.7888
# 筛查标准：
# TP:1163, FP:1486, TN:8970, FN:187
# Sensibility:0.8615, Specificity:0.8579, Accuracy:0.8583
#   属性_class 诊断标准_count 筛查标准_count
# 0       TP        343       1163
# 1       FP       2306       1486
# 2       TN       8970       8970
# 3       FN        187        187
# 4      敏感性     0.6472     0.8615
# 5      特异性     0.7955     0.8579
# 6      准确性     0.7888     0.8583

# %%
template_last_output_path = r'/Users/edz/Documents/My-work/Daily_work/算法结果统计/mine/导出Result/template_last_excel'
template_last_file = r'/template_last_11806_V3.4.1版本.xlsx'
writer1 = pd.ExcelWriter(template_last_output_path + template_last_file)
Table_image.to_excel(writer1,sheet_name='V3.4.1版本_图片维度',index=None)
writer1.save()

# %% [markdown]
# ## 患者标准

# %%
df.rename(columns={'姓名':'name'},inplace=True)
df.head()
# Out:
#    main_pid name                                   md5  Doctor_standard  Screening_standard  v3.2  doc check1  doc check sick_name sick_name-chuli                                    path  Arithmetic_result
# 0  10374185   艾迪  980e27e19bac3595c979442bc3aeda17.jpg                0                   0     0           0          0        健康              健康  R_788319b735bf5111b3e9e6eebc57df9f.jpg                  0
# 1  10374185   艾迪  c377db0f41c6e4da4fcb005bd5461f68.jpg                0                   0     0           0          0        健康              健康  L_daca7354df0a4ddff060993befc594bf.jpg                  0
# 2  10376875   艾军  3c9e3895f69da41026f308c3e36854ca.jpg                0                   0     0           0          0        健康              健康  R_190410cae8d911541a267e24cf0d99b2.jpg                  0
# 3  10376875   艾军  f88efdef54cf4b7408aa68a89e160ea2.jpg                0                   0     0           0          0        健康              健康  L_5bf00f2f255834e28d22dc31cf64e8f2.jpg                  0
# 4  10374579   艾鑫  52b12a8c1428e4b464d5fed6099c3c9e.jpg                0                   0     0           0          0      屈光不正               #  L_2f55506360af7b4a2dfea5f22d7fae09.jpg                  0

# %%
df_patient = df[['name','Doctor_standard','Screening_standard','Arithmetic_result']].groupby(by=df['name'],sort=False).sum()
df_patient.head()
# Out:
#       Doctor_standard  Screening_standard  Arithmetic_result
# name
# 艾迪                  0                   0                  0
# 艾军                  0                   0                  0
# 艾鑫                  0                   0                  0
# 安法元                 0                   0                  0
# 安夫国                 0                   0                  0

# %%
df_patient['Doctor_standard'].value_counts()
# Out:
# 0    4917
# 1     354
# Name: Doctor_standard, dtype: int64

# %%
df_patient['Doctor_standard'].replace([2,3,4], 1 ,inplace=True)  #替换>1的项的值为1，其余不变~
df_patient['Screening_standard'].replace([2,3,4], 1 ,inplace=True)
df_patient['Arithmetic_result'].replace([2,3,4], 1 ,inplace=True)

# %%
df_patient['Screening_standard'].value_counts()
# Out:
# 0    4264
# 1    1007
# Name: Screening_standard, dtype: int64

# %%
df_patient.columns
# Out:
# Index(['Doctor_standard', 'Screening_standard', 'Arithmetic_result'], dtype='object')

# %%
print('V3.4.1——患者维度：(患者共计：{}人)'.format(len(df_patient)))
classification_stantistics_fun(df_patient)
# Out:
# V3.4.1——患者维度：(患者共计：5271人)
# 诊断标准：
# TP:266, FP:1751, TN:3162, FN:88
# Sensibility:0.7514, Specificity:0.6436, Accuracy:0.6508
# 筛查标准：
# TP:917, FP:1100, TN:3162, FN:88
# Sensibility:0.9124, Specificity:0.7419, Accuracy:0.7744
#   属性_class 诊断标准_count 筛查标准_count
# 0       TP        266        917
# 1       FP       1751       1100
# 2       TN       3162       3162
# 3       FN         88         88
# 4      敏感性     0.7514     0.9124
# 5      特异性     0.6436     0.7419
# 6      准确性     0.6508     0.7744

# %%
df.rename(columns={'Doctor_standard':'Doctor_standard_V3.4.1',
                        'Screening_standard':'Screening_standard_V3.4.1'},inplace=True)
template_last_output_path = r'/Users/edz/Documents/My-work/Daily_work/算法结果统计/mine/导出Result/template_last_excel'
template_last_file = r'/template_last_11806_V3.4.1版本.xlsx'
writer2 = pd.ExcelWriter(template_last_output_path + template_last_file)
df.to_excel(writer2,sheet_name='V3.4.1版本_总表',index=None)
writer2.save()

# %%
template_last_output_path = r'/Users/edz/Documents/My-work/Daily_work/算法结果统计/mine/导出Result/template_last_excel'
template_last_file = r'/template_last_11806_V3.4.1版本.xlsx'
writer2 = pd.ExcelWriter(template_last_output_path + template_last_file)
Table_image.to_excel(writer2,sheet_name='V3.4.1版本_患者维度',index=None)
writer2.save()

# %%
df_copy = df   # 备份df表
df_copy.rename(columns={'Doctor_standard':'Doctor_standard_V3.4.1',
                        'Screening_standard':'Screening_standard_V3.4.1'},inplace=True)
df_copy.head()
