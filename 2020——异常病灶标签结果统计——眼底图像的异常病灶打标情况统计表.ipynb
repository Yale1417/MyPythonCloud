# %%
import pandas as pd 
import numpy as np
import os
import shutil
import re
import math 
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)
pd.set_option("expand.frame_repr",False)
print("import succed!")
# Out:
# import succed!

# %%
# 设置——两库全量_and_疾病标签_总表的导入路径
input_path = r'/Users/edz/Documents/yandi_data/AI_data/zn_dc_ai总表/总表_Last'
input_path_file = r'/两库全量_and_lr双疾病标签_lr眼_总表_815098.xlsx'

# %%
df = pd.read_excel(input_path+input_path_file,sep='\t',index_col=None)
df.tail(2)
# Out:
#          来自检查id                 送阅时间  病例医院名称        阅片医院名称  病历医生id 病例医生名称  阅片医生id 阅片医生名称    病史  全身病 病例诊断                               影像描述   阅片诊断 质控影像描述 质控阅片诊断                                 主诉、病例检查、处理、处方json串     来自图片id                                图像地址                           图像md5信息  nId sImagePath  nIsDisable sImageMd5 sBosobject  nCheckImageId nTagCheckDevice  nImageType  arithmeticTag  图像类别  nSugarClass  nDmeClass  nLabelTag  nInferiorTag left_糖网 right_糖网 left_青光眼 right_青光眼 left_屈光不正 right_屈光不正 left_白内障 right_白内障                              md5值                              MD5值  左右眼 left_玻璃体浑浊 right_玻璃体浑浊 left_高血压性视网膜病变 right_高血压性视网膜病变 left_视网膜色素上皮改变 right_视网膜色素上皮改变 left_结晶样视网膜变性 right_结晶样视网膜变性 left_视网膜血管炎 right_视网膜血管炎 left_视网膜血管阻塞 right_视网膜血管阻塞 left_大视杯 right_大视杯 left_屈光间质浑浊 right_屈光间质浑浊 left_结膜炎 right_结膜炎 left_色素膜炎 right_色素膜炎 left_脉络膜骨瘤 right_脉络膜骨瘤 left_眼底出血 right_眼底出血 left_特发性脉络膜新生血管 right_特发性脉络膜新生血管 left_巩膜炎 right_巩膜炎 left_视盘发育异常 right_视盘发育异常 left_视网膜前膜 right_视网膜前膜 left_Coats病 right_Coats病 left_晶体脱位 right_晶体脱位 left_视盘水肿 right_视盘水肿 left_视神经病变 right_视神经病变 left_视神经萎缩 right_视神经萎缩 left_眼底血管样条纹 right_眼底血管样条纹 left_视网膜脱离 right_视网膜脱离 left_闪辉性玻璃体液化 right_闪辉性玻璃体液化 left_后发障 right_后发障  left_Purtscher视网膜病变 right_Purtscher视网膜病变 left_视网膜有髓神经纤维 right_视网膜有髓神经纤维 left_病理性近视 right_病理性近视 left_黑色素细胞瘤 right_黑色素细胞瘤 left_脉络膜缺损 right_脉络膜缺损 left_色素痣 right_色素痣 left_视网膜震荡 right_视网膜震荡 left_黄斑病变 right_黄斑病变 left_脉络膜血管瘤 right_脉络膜血管瘤 left_无晶状体眼 right_无晶状体眼 left_玻璃体出血 right_玻璃体出血 left_视神经炎 right_视神经炎 left_早产儿视网膜病变ROP right_早产儿视网膜病变ROP left_视网膜劈裂症 right_视网膜劈裂症 left_视网膜色素变性 right_视网膜色素变性 left_息肉样脉络膜血管病变PCV right_息肉样脉络膜血管病变PCV left_占位性病变 right_占位性病变 left_虹膜炎 right_虹膜炎 left_缺血性视神经病变 right_缺血性视神经病变 left_星状玻璃体变性 right_星状玻璃体变性 left_视盘缺损 right_视盘缺损 
         NaN          NaN        NaN         NaN      NaN       NaN        NaN         NaN       NaN        NaN         NaN          NaN        NaN         NaN        NaN         NaN       NaN        NaN              NaN               NaN         NaN          NaN          NaN           NaN                NaN                 NaN        NaN         NaN      NaN       NaN           NaN            NaN          NaN           NaN       NaN        NaN           NaN            NaN          NaN           NaN         NaN          NaN       NaN        NaN        NaN         NaN        NaN         NaN        NaN         NaN         NaN          NaN     NaN      NaN

# %%
df.shape  # 查看行列容量
# Out:
# (815098, 154)

# %%
# 筛选有效列数据
df_pre = df[['来自图片id','来自检查id','左右眼','影像描述','阅片诊断','图像地址','图像md5信息','图像类别','nTagCheckDevice']]

# %%
df_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815098 entries, 0 to 815097
# Data columns (total 9 columns):
# 来自图片id             813418 non-null float64
# 来自检查id             815098 non-null int64
# 左右眼                420934 non-null float64
# 影像描述               772736 non-null object
# 阅片诊断               815098 non-null object
# 图像地址               815098 non-null object
# 图像md5信息            813418 non-null object
# 图像类别               607971 non-null float64
# nTagCheckDevice    298262 non-null object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 56.0+ MB

# %% [markdown]
# ### pd.isnull(z.at[815076,'arithmeticTag'])==True  # Dataframe判断一列中某值是否为空

# %% [markdown]
# #### 根据有"nTagCheckDevice"字段的根据字段内容，定义图像类型；没有的则根据"arithmeticTag"(即：32分类)字段内容，定义图像类型。

# %% [markdown]
# ### 影像描述——异常病灶标签读入

# %%
# 读入眼底异常病灶签列
input_path_bq = r'/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签'
dir_list_bq = os.listdir(input_path_bq)  # 获取被筛选文件夹中所有的文件名称
print(dir_list_bq)  # 绝对路径
# Out:
# ['RNFLD_quan_250625.xlsx', '.DS_Store', '中心凹改变_quan_250625.xlsx', '血管异常_quan_250625.xlsx', '囊样水肿_quan_250625.xlsx', '晶体皮质混浊_quan_250625.xlsx', '黄斑区增厚_quan_250625.xlsx', '动脉血管反光强_quan_250625.xlsx', '水肿_quan_250625.xlsx', '皱褶_quan_250625.xlsx', '血管硬化_quan_250625.xlsx', '血管变细_quan_250625.xlsx', '色素变性_quan_250625.xlsx', '脉络膜缺损_quan_250625.xlsx', '脱离_quan_250625.xlsx', '色素沉着_quan_250625.xlsx', 'pre', '变薄_quan_250625.xlsx', '裂孔_quan_250625.xlsx', '血管闭塞_quan_250625.xlsx', '血管瘤_quan_250625.xlsx', '黄白色病灶_quan_250625.xlsx', '盘沿窄_quan_250625.xlsx', '色素脱失_quan_250625.xlsx', '色素紊乱_quan_250625.xlsx']

# %% [markdown]
# pandas中规定，只要数值类型列，有缺失值，那么这一列的数据类型就是浮点型，所以不能强制转换为整型，不然会报错——ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
file_dir_list_bq = [os.path.join(input_path_bq, x) for x in dir_list_bq]
print(file_dir_list_bq)
# Out:
# ['/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/RNFLD_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/.DS_Store', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/中心凹改变_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/血管异常_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/囊样水肿_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/晶体皮质混浊_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/黄斑区增厚_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/动脉血管反光强_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/水肿_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/皱褶_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/血管硬化_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/血管变细_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/色素变性_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/脉络膜缺损_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/脱离_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/色素沉着_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/pre', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/变薄_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/裂孔_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/血管闭塞_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/血管瘤_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/黄白色病灶_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/盘沿窄_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/色素脱失_quan_250625.xlsx', '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/色素紊乱_quan_250625.xlsx']

# %%
a = 'zn_ai_影像描述标签/变薄_quan_250625.xlsx'
if a.endwith('.xlsx'):
    print('yes')
else:
    print('no')

# %%
# 读入标签数据
for i in range(len(file_dir_list_bq)):
    if file_dir_list_bq[i] == '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/.DS_Store':
        pass
    elif file_dir_list_bq[i] == '/Users/edz/Documents/yandi_data/AI_data/zn_ai_影像描述标签/pre':
        pass
    else:
        df_bq_i = pd.read_excel(file_dir_list_bq[i], usecols=[0,2,3], sep='\t',index_col=None) 
        if i == 0:
            df_bq = df_bq_i  # 首次赋值==原始表
        else:
            df_bq = df_bq.merge(df_bq_i,how='left',on='来自检查id')  # 之后添加新标签表

print("合表后，异常病灶标签表的数据容量{}".format(df_bq.columns.shape[0]))
    # df_bq_1.head(2)
# Out:
# 合表后，异常病灶标签表的数据容量47

# %%
df_bq.shape[0]
# Out:
# 250625

# %%
df_bq.columns
# Out:
# Index(['来自检查id', 'left_RNFLD', 'right_RNFLD', 'left_中心凹改变', 'right_中心凹改变',
#        'left_血管异常', 'right_血管异常', 'left_囊样水肿', 'right_囊样水肿', 'left_晶体皮质混浊',
#        'right_晶体皮质混浊', 'left_黄斑区增厚', 'right_黄斑区增厚', 'left_动脉血管反光强',
#        'right_动脉血管反光强', 'left_水肿', 'right_水肿', 'left_皱褶', 'right_皱褶',
#        'left_血管硬化', 'right_血管硬化', 'left_血管变细', 'right_血管变细', 'left_色素变性',
#        'right_色素变性', 'left_脉络膜缺损', 'right_脉络膜缺损', 'left_脱离', 'right_脱离',
#        'left_色素沉着', 'right_色素沉着', 'left_变薄', 'right_变薄', 'left_裂孔', 'right_裂孔',
#        'left_血管闭塞', 'right_血管闭塞', 'left_血管瘤', 'right_血管瘤', 'left_黄白色病灶',
#        'right_黄白色病灶', 'left_盘沿窄', 'right_盘沿窄', 'left_色素脱失', 'right_色素脱失',
#        'left_色素紊乱', 'right_色素紊乱'],
#       dtype='object')

# %%
df_zong = df_pre.merge(df_bq, how='left', on='来自检查id')

# %%
df_zong.tail(2)
# Out:
#            来自图片id   来自检查id  左右眼                               影像描述   阅片诊断                                图像地址                           图像md5信息  图像类别 nTagCheckDevice left_RNFLD right_RNFLD left_中心凹改变 right_中心凹改变 left_血管异常 right_血管异常 left_囊样水肿 right_囊样水肿 left_晶体皮质混浊 right_晶体皮质混浊 left_黄斑区增厚 right_黄斑区增厚 left_动脉血管反光强 right_动脉血管反光强 left_水肿 right_水肿 left_皱褶 right_皱褶 left_血管硬化 right_血管硬化 left_血管变细 right_血管变细 left_色素变性 right_色素变性 left_脉络膜缺损 right_脉络膜缺损 left_脱离 right_脱离 left_色素沉着 right_色素沉着 left_变薄 right_变薄 left_裂孔 right_裂孔 left_血管闭塞 right_血管闭塞 left_血管瘤 right_血管瘤 left_黄白色病灶 right_黄白色病灶 left_盘沿窄 right_盘沿窄 left_色素脱失 right_色素脱失 left_色素紊乱 right_色素紊乱
# 815096  6745662.0  2021369  2.0  双眼晶体皮质混浊，眼底：双眼眼底朦胧，隐见视盘及大血管，余结构不详  双眼白内障  eznkSljGUBOAVYMLAAHj3a8oCcE216.jpg  be4c01d657c893f3550fd47b2109d68a  11.0             NaN        NaN         NaN        NaN         NaN       NaN        NaN       NaN        NaN      晶体皮质混浊       晶体皮质混浊        NaN         NaN          NaN           NaN     NaN      NaN     NaN      NaN       NaN        NaN       NaN        NaN       NaN        NaN        NaN         NaN     NaN      NaN       NaN        NaN     NaN      NaN     NaN      NaN       NaN        NaN      NaN       NaN        NaN         NaN      NaN       NaN       NaN        NaN       NaN        NaN
# 815097  6745663.0  2021369  NaN  双眼晶体皮质混浊，眼底：双眼眼底朦胧，隐见视盘及大血管，余结构不详  双眼白内障  eznkSljGUBOASwaHAAJJ4utlT0w072.jpg                             empty   6.0             NaN        NaN         NaN        NaN         NaN       NaN        NaN       NaN        NaN      晶体皮质混浊       晶体皮质混浊        NaN         NaN          NaN           NaN     NaN      NaN     NaN      NaN       NaN        NaN       NaN        NaN       NaN        NaN        NaN         NaN     NaN      NaN       NaN        NaN     NaN      NaN     NaN      NaN       NaN        NaN      NaN       NaN        NaN         NaN      NaN       NaN       NaN        NaN       NaN        NaN

# %%
df_zong.columns
# Out:
# Index(['来自图片id', '来自检查id', '左右眼', '影像描述', '阅片诊断', '图像地址', '图像md5信息', '图像类别',
#        'nTagCheckDevice', 'left_RNFLD', 'right_RNFLD', 'left_中心凹改变',
#        'right_中心凹改变', 'left_血管异常', 'right_血管异常', 'left_囊样水肿', 'right_囊样水肿',
#        'left_晶体皮质混浊', 'right_晶体皮质混浊', 'left_黄斑区增厚', 'right_黄斑区增厚',
#        'left_动脉血管反光强', 'right_动脉血管反光强', 'left_水肿', 'right_水肿', 'left_皱褶',
#        'right_皱褶', 'left_血管硬化', 'right_血管硬化', 'left_血管变细', 'right_血管变细',
#        'left_色素变性', 'right_色素变性', 'left_脉络膜缺损', 'right_脉络膜缺损', 'left_脱离',
#        'right_脱离', 'left_色素沉着', 'right_色素沉着', 'left_变薄', 'right_变薄', 'left_裂孔',
#        'right_裂孔', 'left_血管闭塞', 'right_血管闭塞', 'left_血管瘤', 'right_血管瘤',
#        'left_黄白色病灶', 'right_黄白色病灶', 'left_盘沿窄', 'right_盘沿窄', 'left_色素脱失',
#        'right_色素脱失', 'left_色素紊乱', 'right_色素紊乱'],
#       dtype='object')

# %%
df_zong['图像类别'].notnull().sum()  # 存在32分类标签图片的数据总量
# Out:
# 607971

# %%
df_zong['图像类别'].isnull().sum()  # 不存在32分类标签图片的数据总量
# Out:
# 207127

# %%
a = df_zong.drop_duplicates(subset='图像地址',keep='first')

# %%
a.shape[0]
# Out:
# 639523

# %%
a[a['图像地址'].duplicated()==True].shape[0]

# %% [markdown]
# ###### 取差集 c = list(set(a).difference(set(b)))

# %%
a = df_zong.columns.tolist()
a =  [a[i].replace('right_','') for i in range(len(a))]  # replace函数实现str的替换
a =  [a[i].replace('left_','') for i in range(len(a))]
b = a[9:]
# 得到新增列名称的列表
x = list(set(b))  # 去重得到新增项列表名称——合并标签
print(x)  #  新增列名称的列表
# Out:
# ['血管闭塞', '囊样水肿', '脱离', '血管硬化', '动脉血管反光强', '中心凹改变', '色素脱失', '变薄', '色素紊乱', '血管变细', '图像md5信息', '图像地址', '裂孔', '血管异常', '黄白色病灶', '黄斑区增厚', '盘沿窄', '皱褶', '血管瘤', '阅片诊断', 'nTagCheckDevice', '晶体皮质混浊', 'RNFLD', '色素变性', '水肿', '色素沉着', '图像类别', '脉络膜缺损']

# %%
# 插入合并疾病标签的数据列
insert_index = df_zong.columns.get_loc('影像描述')
insert_columns_list = x
# 插入指定列
for i in range(len(insert_columns_list)):
    df_zong.insert(insert_index+(i+1),insert_columns_list[i],None)

# %%
print(df_zong.columns)
# Out:
# Index(['来自图片id', '来自检查id', '左右眼', '影像描述', '血管闭塞', '囊样水肿', '脱离', '血管硬化',
#        '动脉血管反光强', '中心凹改变', '色素脱失', '血管变细', '变薄', '色素紊乱', '裂孔', '血管异常', '黄白色病灶',
#        '黄斑区增厚', '盘沿窄', '皱褶', '血管瘤', '晶体皮质混浊', 'RNFLD', '色素变性', '水肿', '色素沉着',
#        '脉络膜缺损', '阅片诊断', '图像地址', '图像md5信息', '图像类别', 'nTagCheckDevice',
#        'left_RNFLD', 'right_RNFLD', 'left_中心凹改变', 'right_中心凹改变', 'left_血管异常',
#        'right_血管异常', 'left_囊样水肿', 'right_囊样水肿', 'left_晶体皮质混浊', 'right_晶体皮质混浊',
#        'left_黄斑区增厚', 'right_黄斑区增厚', 'left_动脉血管反光强', 'right_动脉血管反光强', 'left_水肿',
#        'right_水肿', 'left_皱褶', 'right_皱褶', 'left_血管硬化', 'right_血管硬化',
#        'left_血管变细', 'right_血管变细', 'left_色素变性', 'right_色素变性', 'left_脉络膜缺损',
#        'right_脉络膜缺损', 'left_脱离', 'right_脱离', 'left_色素沉着', 'right_色素沉着',
#        'left_变薄', 'right_变薄', 'left_裂孔', 'right_裂孔', 'left_血管闭塞', 'right_血管闭塞',
#        'left_血管瘤', 'right_血管瘤', 'left_黄白色病灶', 'right_黄白色病灶', 'left_盘沿窄',
#        'right_盘沿窄', 'left_色素脱失', 'right_色素脱失', 'left_色素紊乱', 'right_色素紊乱'],
#       dtype='object')

# %%
len(insert_columns_list)
# Out:
# 23

# %% [markdown]
# #### 根据左右眼标签识别唯一的眼底图对应疾病标签

# %%
# 根据左右眼标签识别唯一的眼底图对应疾病标签
for k in range(len(x)):
    for i in range(df_zong.shape[0]):  
        str_i = df_zong.at[i,'左右眼']
        if  str_i == 0: # 左眼
            df_zong.at[i, x[k]] = df_zong.at[i,'left_' + x[k]]
        elif str_i == 1:
            df_zong.at[i, x[k]] = df_zong.at[i,'right_' + x[k]]
        else:
            pass

# %%
df_zong.loc[20:25,:]  # 查验
# Out:
# %%
# 根据”左眼标签==右眼标签“识别图片对应的疾病标签
def lr_equal_func(df,l_column,r_column,equal_column):
    for j in range(df.shape[0]):
        if pd.isnull(df.at[j,equal_column])==False:
            pass
        else:
            if df.at[j,l_column] == df.at[j,r_column]:
                df.at[j,equal_column] = df.at[j,l_column]
    #             print(df_last.at[j,'糖网'])
            else:
                pass

# %%
# # 调用疾病标签合并的打标函数
for k in range(len(x)):
    print("处理——{}列：".format(x[k]))
    lr_equal_func(df_zong,'left_' + x[k],'right_' + x[k], x[k])
# Out:
# 处理——血管闭塞列：
# 处理——囊样水肿列：
# 处理——脱离列：
# 处理——血管硬化列：
# 处理——动脉血管反光强列：
# 处理——中心凹改变列：
# 处理——色素脱失列：
# 处理——血管变细列：
# 处理——变薄列：
# 处理——色素紊乱列：
# 处理——裂孔列：
# 处理——血管异常列：
# 处理——黄白色病灶列：
# 处理——黄斑区增厚列：
# 处理——盘沿窄列：
# 处理——皱褶列：
# 处理——血管瘤列：
# 处理——晶体皮质混浊列：
# 处理——RNFLD列：
# 处理——色素变性列：
# 处理——水肿列：
# 处理——色素沉着列：
# 处理——脉络膜缺损列：

# %% [markdown]
# ### 导出影像描述_异常病灶标签_总表

# %%
# 导出最终的全量总表——右、右眼两列疾病标签
out_put_path = r'/Users/edz/Documents/yandi_data/AI_data/zn_dc_ai总表/影像描述_异常病灶总表'
out_put_file = r'/影像描述_异常病灶标签_总表_hou_815098.xlsx'
writer = pd.ExcelWriter(out_put_path + out_put_file)
df_zong.to_excel(writer,sheet_name='607971条已解析图像类别',index=None)
writer.save()

# %% [markdown]
# ## 筛选、截取下载样例图像的初始文件TXT——相关数据
# #### 筛选眼底图数据——用于统计表的制作

# %%
## 筛选下载样图的数据标签列
df_zong.columns.get_loc('left_RNFLD')
df_zong_image = df_zong.iloc[:,:32]  # 选取最终的病灶标签
df_zong_image.info()  # 校验已打标数据总量

# %%
# 筛选眼底图像数据
df_zong_image_yd = df_zong_image[df_zong_image['图像类别']==11]
df_zong_image_yd.reset_index(drop=True,inplace=True)

# %%
df_zong_image_yd.tail(2)
# Out:
#            来自图片id   来自检查id  左右眼                               影像描述  血管闭塞  囊样水肿    脱离  血管硬化 动脉血管反光强 中心凹改变  色素脱失  血管变细    变薄          色素紊乱    裂孔  血管异常 黄白色病灶 黄斑区增厚   盘沿窄    皱褶   血管瘤  晶体皮质混浊 RNFLD  色素变性    水肿  色素沉着 脉络膜缺损     阅片诊断                                图像地址                           图像md5信息  图像类别 nTagCheckDevice
# 504332  6745855.0  2021416  0.0         双眼视盘界清，黄斑区色素紊乱，余可见部未见典型异常。   NaN   NaN   NaN   NaN     NaN   NaN   NaN   NaN   NaN  色素紊乱,黄斑区色素紊乱   NaN   NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN   NaN   NaN   NaN  双眼底大致正常  eznkSljGUCKABClsAAJoajRYNLg889.jpg  16c5b9ca7f2be474068846618b1d7054  11.0             NaN
# 504333  6745662.0  2021369  2.0  双眼晶体皮质混浊，眼底：双眼眼底朦胧，隐见视盘及大血管，余结构不详  None  None  None  None    None  None  None  None  None          None  None  None  None  None  None  None  None  晶体皮质混浊  None  None  None  None  None    双眼白内障  eznkSljGUBOAVYMLAAHj3a8oCcE216.jpg  be4c01d657c893f3550fd47b2109d68a  11.0             NaN

# %%
df_zong_image_yd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 504334 entries, 0 to 504333
# Data columns (total 32 columns):
# 来自图片id             504334 non-null float64
# 来自检查id             504334 non-null int64
# 左右眼                420156 non-null float64
# 影像描述               486649 non-null object
# 血管闭塞               2814 non-null object
# 囊样水肿               347 non-null object
# 脱离                 2155 non-null object
# 血管硬化               35444 non-null object
# 动脉血管反光强            16045 non-null object
# 中心凹改变              2622 non-null object
# 色素脱失               764 non-null object
# 血管变细               67002 non-null object
# 变薄                 2201 non-null object
# 色素紊乱               4983 non-null object
# 裂孔                 790 non-null object
# 血管异常               261 non-null object
# 黄白色病灶              5303 non-null object
# 黄斑区增厚              104 non-null object
# 盘沿窄                8264 non-null object
# 皱褶                 1715 non-null object
# 血管瘤                14823 non-null object
# 晶体皮质混浊             12776 non-null object
# RNFLD              9637 non-null object
# 色素变性               6242 non-null object
# 水肿                 7939 non-null object
# 色素沉着               3392 non-null object
# 脉络膜缺损              197 non-null object
# 阅片诊断               504334 non-null object
# 图像地址               504334 non-null object
# 图像md5信息            504334 non-null object
# 图像类别               504334 non-null float64
# nTagCheckDevice    296501 non-null object
# dtypes: float64(3), int64(1), object(28)
# memory usage: 123.1+ MB

# %% [markdown]
# ## 输出需要下载样例图像的初始文件TXT

# %%
column_start = df_zong_image_yd.columns.get_loc('影像描述')  # 病灶标签起始位置
print('病灶标签起始位置:{}'.format(column_start))
column_end = df_zong_image_yd.columns.get_loc('阅片诊断')  # 病灶标签终止位置
print('病灶标签终止位置:{}'.format(column_end))
# Out:
# 病灶标签起始位置:3
# 病灶标签终止位置:27

# %%
# 异常病灶标签list
bz_columns = df_zong_image_yd.columns.to_list()
bz_columns = bz_columns[column_start+1:column_end]  # 截取病灶标签list
print(bz_columns)
# Out:
# ['血管闭塞', '囊样水肿', '脱离', '血管硬化', '动脉血管反光强', '中心凹改变', '色素脱失', '血管变细', '变薄', '色素紊乱', '裂孔', '血管异常', '黄白色病灶', '黄斑区增厚', '盘沿窄', '皱褶', '血管瘤', '晶体皮质混浊', 'RNFLD', '色素变性', '水肿', '色素沉着', '脉络膜缺损']

# %%
# 需要下载的异常病灶文件list————————————————姜博需求
bz_xy_list = ['微血管瘤','出血斑','硬性渗出','软性渗出','静脉串珠','微血管异常','新生血管','静脉环',
          '增殖膜','视网膜前出血','视网膜深层出血','玻璃膜疣','近视萎缩弧','裂孔','前膜','水肿','有髓神经纤维','动静脉压迹',
          '视盘水肿','铜丝样改变','银丝样改变','静脉闭塞','神经纤维缺损','黄斑地图样萎缩灶']

# %%
df_zong_image_yd['血管瘤'].value_counts()
# Out:
# 血管瘤,微血管瘤           7838
# 血管瘤,动脉瘤            4703
# 血管瘤,微动脉瘤           2203
# 血管瘤                  78
# 血管瘤,动脉瘤;血管瘤,动脉瘤       1
# Name: 血管瘤, dtype: int64

# %%
df_zong_image_yd[df_zong_image_yd['出血shape'].isin(['出血,出血斑'])].shape[0]

# %%
for i in range(len(bz_columns)):
    print('处理列——{}'.format(bz_columns[i]))
    df_tempt = pd.DataFrame(data=df_zong_image_yd[bz_columns[i]].value_counts())
    df_tempt.reset_index(drop=False,inplace=True) # 还原索引列为普通列
    df_tempt.columns=['name','number']  #直接更改全部的列名称——这种方式需要将全部列名列出，作为list列表类型返回给df1.columns
    values_list = df_tempt['name'].to_list()  # 列出可能的values列表
#     print(values_list)
    str_find_list = []
    for j in range(len(bz_xy_list)):
    #     print(bz_xy_list[j])
        for k in range(len(values_list)):
            if bz_xy_list[j] in values_list[k]:
                str_find = values_list[k]
                str_find_list.append(str_find)
            else:
                pass
    str_find_list = list(set(str_find_list))
    str_find_list = [(str_find_list[g]) for g in range(len(str_find_list)) if ';' not in str_find_list[g]]  # 剔除“多标签”
    if len(str_find_list) > 0:
        print('匹配到value值:{}'.format(str_find_list))
        for l in range(len(str_find_list)):
            print('===========输出病灶——{}'.format(str_find_list[l]))
            df_k = df_zong_image_yd[df_zong_image_yd[bz_columns[i]].isin([str_find_list[l]])]  # 获取包含指定字符value的DataFrame
            df_k.reset_index(drop=True,inplace=True)
            print('df_k的shape为{}_____________'.format(df_k.shape[0]))
            df_k = df_k.loc[:,['图像地址']]   # 取满足指定条件的图片的’图像地址‘列
            df_k.insert(1,column='bucket',value='zhizhen-tms')
            df_k.rename(columns={'图像地址':'objectkey'},inplace=True)
            df_k_shape = df_k[:400]  # 输出前200项——修改项
            print('病灶——{0}——的数据容量:{1}'.format(str_find_list[l], df_k_shape.shape[0]))
            # 导出最终的txt文件
            out_put_path = '/Users/edz/Documents/yandi_data/taishi_loading/load_image/原始TXT表'
            out_put_file = '/' + str_find_list[l].split(',')[-1] +'.txt'
            df_k_shape.to_csv(out_put_path+out_put_file,sep='\t',index=None)
    else:
        pass
# Out:
# 处理列——血管闭塞
# 匹配到value值:['血管闭塞,静脉闭塞']
# ===========输出病灶——血管闭塞,静脉闭塞
# df_k的shape为315_____________
# 病灶——血管闭塞,静脉闭塞——的数据容量:315
# 处理列——囊样水肿
# 匹配到value值:['囊样水肿']
# ===========输出病灶——囊样水肿
# df_k的shape为347_____________
# 病灶——囊样水肿——的数据容量:347
# 处理列——脱离
# 处理列——血管硬化
# 处理列——动脉血管反光强
# 处理列——中心凹改变
# 处理列——色素脱失
# 处理列——血管变细
# 处理列——变薄
# 处理列——色素紊乱
# 匹配到value值:['色素紊乱,视网膜前膜色素紊乱']
# ===========输出病灶——色素紊乱,视网膜前膜色素紊乱
# df_k的shape为1_____________
# 病灶——色素紊乱,视网膜前膜色素紊乱——的数据容量:1
# 处理列——裂孔
# 匹配到value值:['裂孔,黄斑裂孔', '裂孔,视网膜裂孔', '裂孔']
# ===========输出病灶——裂孔,黄斑裂孔
# df_k的shape为714_____________
# 病灶——裂孔,黄斑裂孔——的数据容量:400
# ===========输出病灶——裂孔,视网膜裂孔
# df_k的shape为34_____________
# 病灶——裂孔,视网膜裂孔——的数据容量:34
# ===========输出病灶——裂孔
# df_k的shape为42_____________
# 病灶——裂孔——的数据容量:42
# 处理列——血管异常
# 匹配到value值:['血管异常,微血管异常']
# ===========输出病灶——血管异常,微血管异常
# df_k的shape为120_____________
# 病灶——血管异常,微血管异常——的数据容量:120
# 处理列——黄白色病灶
# 处理列——黄斑区增厚
# 处理列——盘沿窄
# 处理列——皱褶
# 匹配到value值:['皱褶,前膜皱褶']
# ===========输出病灶——皱褶,前膜皱褶
# df_k的shape为145_____________
# 病灶——皱褶,前膜皱褶——的数据容量:145
# 处理列——血管瘤
# 匹配到value值:['血管瘤,微血管瘤']
# ===========输出病灶——血管瘤,微血管瘤
# df_k的shape为7838_____________
# 病灶——血管瘤,微血管瘤——的数据容量:400
# 处理列——晶体皮质混浊
# 处理列——RNFLD
# 处理列——色素变性
# 处理列——水肿
# 匹配到value值:['水肿,黄斑囊样水肿', '水肿,眼睑水肿', '水肿,黄斑水肿', '水肿,视网膜水肿', '水肿,视盘水肿', '水肿,结膜水肿', '水肿', '水肿,角膜水肿']
# ===========输出病灶——水肿,黄斑囊样水肿
# df_k的shape为294_____________
# 病灶——水肿,黄斑囊样水肿——的数据容量:294
# ===========输出病灶——水肿,眼睑水肿
# df_k的shape为35_____________
# 病灶——水肿,眼睑水肿——的数据容量:35
# ===========输出病灶——水肿,黄斑水肿
# df_k的shape为4018_____________
# 病灶——水肿,黄斑水肿——的数据容量:400
# ===========输出病灶——水肿,视网膜水肿
# df_k的shape为1433_____________
# 病灶——水肿,视网膜水肿——的数据容量:400
# ===========输出病灶——水肿,视盘水肿
# df_k的shape为1615_____________
# 病灶——水肿,视盘水肿——的数据容量:400
# ===========输出病灶——水肿,结膜水肿
# df_k的shape为87_____________
# 病灶——水肿,结膜水肿——的数据容量:87
# ===========输出病灶——水肿
# df_k的shape为265_____________
# 病灶——水肿——的数据容量:265
# ===========输出病灶——水肿,角膜水肿
# df_k的shape为118_____________
# 病灶——水肿,角膜水肿——的数据容量:118
# 处理列——色素沉着
# 处理列——脉络膜缺损

# %% [markdown]
# ### 输出最终结果表——全量标签+病灶标签

# %%
df_last = df.merge(df_bq, how='left', on='来自检查id')

# %%
df.shape  # 全量表的总数据容量

# %%
out_put_path = '/Users/edz/Documents/yandi_data/AI_data/zn_dc_ai总表/影像描述_异常病灶总表'
out_put_file = '两库全量_lr疾病_异常病灶_pre总表_18类.xlsx'
writer = pd.ExcelWriter(out_put_path + out_put_file)
df_last.to_excel(writer, sheet_name='两库全量_lr疾病_异常病灶_pre总表_815098', index=None)
writer.save()

# %% [markdown]
# ## 病灶标签统计表
# #### 筛选眼底图像数据

# %%
# 筛选眼底图像数据
df_zong_yd = df_zong[df_zong['图像类别']==11]
df_zong_yd.reset_index(drop=True,inplace=True)

# %%
df_zong_yd.tail(2)
# Out:
#            来自图片id   来自检查id  左右眼                               影像描述  血管闭塞  囊样水肿    脱离  血管硬化 动脉血管反光强 中心凹改变  色素脱失  血管变细    变薄          色素紊乱    裂孔  血管异常 黄白色病灶 黄斑区增厚   盘沿窄    皱褶   血管瘤  晶体皮质混浊 RNFLD  色素变性    水肿  色素沉着 脉络膜缺损     阅片诊断                                图像地址                           图像md5信息  图像类别 nTagCheckDevice left_RNFLD right_RNFLD left_中心凹改变 right_中心凹改变 left_血管异常 right_血管异常 left_囊样水肿 right_囊样水肿 left_晶体皮质混浊 right_晶体皮质混浊 left_黄斑区增厚 right_黄斑区增厚 left_动脉血管反光强 right_动脉血管反光强 left_水肿 right_水肿 left_皱褶 right_皱褶 left_血管硬化 right_血管硬化 left_血管变细 right_血管变细 left_色素变性 right_色素变性 left_脉络膜缺损 right_脉络膜缺损 left_脱离 right_脱离 left_色素沉着 right_色素沉着 left_变薄 right_变薄 left_裂孔 right_裂孔 left_血管闭塞 right_血管闭塞 left_血管瘤 right_血管瘤 left_黄白色病灶 right_黄白色病灶 left_盘沿窄 right_盘沿窄 left_色素脱失 right_色素脱失     left_色素紊乱    right_色素紊乱
# 504332  6745855.0  2021416  0.0         双眼视盘界清，黄斑区色素紊乱，余可见部未见典型异常。   NaN   NaN   NaN   NaN     NaN   NaN   NaN   NaN   NaN  色素紊乱,黄斑区色素紊乱   NaN   NaN   NaN   NaN   NaN   NaN   NaN     NaN   NaN   NaN   NaN   NaN   NaN  双眼底大致正常  eznkSljGUCKABClsAAJoajRYNLg889.jpg  16c5b9ca7f2be474068846618b1d7054  11.0             NaN        NaN         NaN        NaN         NaN       NaN        NaN       NaN        NaN         NaN          NaN        NaN         NaN          NaN           NaN     NaN      NaN     NaN      NaN       NaN        NaN       NaN        NaN       NaN        NaN        NaN         NaN     NaN      NaN       NaN        NaN     NaN      NaN     NaN      NaN       NaN        NaN      NaN       NaN        NaN         NaN      NaN       NaN       NaN        NaN  色素紊乱,黄斑区色素紊乱  色素紊乱,黄斑区色素紊乱
# 504333  6745662.0  2021369  2.0  双眼晶体皮质混浊，眼底：双眼眼底朦胧，隐见视盘及大血管，余结构不详  None  None  None  None    None  None  None  None  None          None  None  None  None  None  None  None  None  晶体皮质混浊  None  None  None  None  None    双眼白内障  eznkSljGUBOAVYMLAAHj3a8oCcE216.jpg  be4c01d657c893f3550fd47b2109d68a  11.0             NaN        NaN         NaN        NaN         NaN       NaN        NaN       NaN        NaN      晶体皮质混浊       晶体皮质混浊        NaN         NaN          NaN           NaN     NaN      NaN     NaN      NaN       NaN        NaN       NaN        NaN       NaN        NaN        NaN         NaN     NaN      NaN       NaN        NaN     NaN      NaN     NaN      NaN       NaN        NaN      NaN       NaN        NaN         NaN      NaN       NaN       NaN        NaN           NaN           NaN

# %% [markdown]
# #### 导出已打标的眼底图——异常病灶标签表

# %%
out_put_path_yd_ydb = r'/Users/edz/Documents/yandi_data/AI_data/zn_dc_ai总表/影像描述_异常病灶总表'
out_put_file_yd_ydb = r'/眼底图_异常病灶_hou_全量标签表_504334条.xlsx'
writer = pd.ExcelWriter(out_put_path_yd_ydb + out_put_file_yd_ydb)
df_zong_yd.to_excel(writer,sheet_name='眼底图_异常病灶_标签表_'+ str(df_zong_yd.shape[0]),index=None)
writer.save()

# %% [markdown]
# ### 设置变量，统计各疾病标签下的数据量

# %%
##################第一步，统计已打标的图像数量
## 以视网膜血管阻塞为例设计统计函数
def son_statistic_func(df,column_name,contain_strs):
    a = df[df[column_name].notnull()]
    b = a[a[column_name].str.contains(contain_strs)]
    # print(b['视网膜血管阻塞'].value_counts())
    # print(b.shape[0])
    c = pd.DataFrame(data=b[column_name].value_counts())
    c.reset_index(level=0,inplace=True)  # 将索引列转为普通列
    c.rename(columns={c.columns[0]:'病灶子类',c.columns[1]:'已打标眼底图数量'},inplace=True)
    print("c的行列数:{}行*{}列".format(c.shape[0],c.shape[1]))
    if c.shape[0]==1:  # 单一种类病灶标签的直接返回一行
        return c
    else:
        # 多种疾病标签的——新增子类合计行，显示为标准表
        c.loc[c.shape[0]]=c.loc[:,['已打标眼底图数量']].apply(lambda x: x.sum())  # 新增一行用于统计指定列下，各行数据总和，并作为新行添加到末尾
        c.loc[c.shape[0]-1,'病灶子类'] = column_name + '类合计'
        c['已打标眼底图数量'] = c['已打标眼底图数量'].astype(int)  # 将数据强制转为整型
    #     print(c)
        return c

# %% [markdown]
# #### 常见异常病灶

# %%
ydb_table = pd.DataFrame()

# %%
df_zong_yd.columns
# Out:
# Index(['来自图片id', '来自检查id', '左右眼', '影像描述', '血管闭塞', '囊样水肿', '脱离', '血管硬化',
#        '动脉血管反光强', '中心凹改变', '色素脱失', '血管变细', '变薄', '色素紊乱', '裂孔', '血管异常', '黄白色病灶',
#        '黄斑区增厚', '盘沿窄', '皱褶', '血管瘤', '晶体皮质混浊', 'RNFLD', '色素变性', '水肿', '色素沉着',
#        '脉络膜缺损', '阅片诊断', '图像地址', '图像md5信息', '图像类别', 'nTagCheckDevice',
#        'left_RNFLD', 'right_RNFLD', 'left_中心凹改变', 'right_中心凹改变', 'left_血管异常',
#        'right_血管异常', 'left_囊样水肿', 'right_囊样水肿', 'left_晶体皮质混浊', 'right_晶体皮质混浊',
#        'left_黄斑区增厚', 'right_黄斑区增厚', 'left_动脉血管反光强', 'right_动脉血管反光强', 'left_水肿',
#        'right_水肿', 'left_皱褶', 'right_皱褶', 'left_血管硬化', 'right_血管硬化',
#        'left_血管变细', 'right_血管变细', 'left_色素变性', 'right_色素变性', 'left_脉络膜缺损',
#        'right_脉络膜缺损', 'left_脱离', 'right_脱离', 'left_色素沉着', 'right_色素沉着',
#        'left_变薄', 'right_变薄', 'left_裂孔', 'right_裂孔', 'left_血管闭塞', 'right_血管闭塞',
#        'left_血管瘤', 'right_血管瘤', 'left_黄白色病灶', 'right_黄白色病灶', 'left_盘沿窄',
#        'right_盘沿窄', 'left_色素脱失', 'right_色素脱失', 'left_色素紊乱', 'right_色素紊乱'],
#       dtype='object')

# %%
df_zong_yd['脉络膜缺损'].value_counts()
# Out:
# 脉络膜缺损    197
# Name: 脉络膜缺损, dtype: int64

# %%
# # 处理“包含str”与列名不同的情形
# ydb_table = ydb_table.append(son_statistic_func(df_zong_yd,'出血location','出血'),ignore_index=True)
# ydb_table = ydb_table.append(son_statistic_func(df_zong_yd,'出血level','出血'),ignore_index=True)
# ydb_table = ydb_table.append(son_statistic_func(df_zong_yd,'出血shape','出血'),ignore_index=True)

# %%
# # 统计处理“杯盘比”和“动静脉管径比”
# dj = son_statistic_func(df_zong_yd,'动静脉管径比','A/V')
# ydb_table = ydb_table.append(dj.iloc[-1,:] ,ignore_index=True) # dj.iloc[-1,:]  # 截取最后一行数据
# # 处理杯盘比
# bp_num = df_zong_yd['杯盘比C/D'].notnull().sum()  # 统计杯盘比总量
# bp = pd.DataFrame(data={'病灶子类':['杯盘比C/D'],'已打标眼底图数量':[bp_num]})
# ydb_table = ydb_table.append(bp.iloc[-1,:] ,ignore_index=True) # dj.iloc[-1,:]  # 截取最后一行数据

# %%
# 统计“包含str”与列名相同的情形
# 定义“包含str”与列名相同的情形的列名list
y = ['血管闭塞', '囊样水肿', '脱离', '血管硬化','动脉血管反光强', '中心凹改变', '色素脱失', '血管变细', '变薄',
     '色素紊乱', '裂孔', '黄白色病灶','黄斑区增厚', '盘沿窄', '皱褶', '血管瘤', '晶体皮质混浊', 'RNFLD', '色素变性',
     '水肿', '色素沉着', '脉络膜缺损']

# %%
for i in range(len(y)):
    ydb_table = ydb_table.append(son_statistic_func(df_zong_yd, y[i], y[i]),ignore_index=True)
# Out:
# c的行列数:3行*2列
# c的行列数:1行*2列
# c的行列数:10行*2列
# c的行列数:2行*2列
# c的行列数:1行*2列
# c的行列数:5行*2列
# c的行列数:1行*2列
# c的行列数:3行*2列
# c的行列数:5行*2列
# c的行列数:4行*2列
# c的行列数:3行*2列
# c的行列数:5行*2列
# c的行列数:1行*2列
# c的行列数:1行*2列
# c的行列数:7行*2列
# c的行列数:5行*2列
# c的行列数:1行*2列
# c的行列数:1行*2列
# c的行列数:3行*2列
# c的行列数:14行*2列
# c的行列数:3行*2列
# c的行列数:1行*2列

# %%
ydb_table
# Out:
#                               病灶子类  已打标眼底图数量
# 0                             血管闭塞      1676
# 1                        血管闭塞,动脉闭塞       823
# 2                        血管闭塞,静脉闭塞       315
# 3                          血管闭塞类合计      2814
# 4                             囊样水肿       347
# 5                       脱离,神经上皮层脱离       906
# 6                         脱离,视网膜脱离       698
# 7                        脱离,玻璃体后脱离       305
# 8                          脱离,黄斑脱离       133
# 9                       脱离,色素上皮层脱离        82
# 10             脱离,视网膜脱离;脱离,神经上皮层脱离        19
# 11              脱离,黄斑脱离;脱离,神经上皮层脱离         6
# 12                      脱离,神经纤维层脱离         3
# 13  脱离,视网膜脱离;脱离,神经上皮层脱离;脱离,色素上皮层脱离         2
# 14   脱离,黄斑脱离;脱离,神经上皮层脱离;脱离,色素上皮层脱离         1
# 15                           脱离类合计      2155
# 16                       血管硬化,动脉硬化     35424
# 17                            血管硬化        20
# 18                         血管硬化类合计     35444
# 19                         动脉血管反光强     16045
# 20                   中心凹改变,中心凹反光消失      1795
# 21                   中心凹改变,中心凹反光不清       773
# 22                   中心凹改变,中心凹反光弥散        48
# 23                   中心凹改变,中心凹反光增强         4
# 24                     中心凹改变,中心凹变平         2
# 25                        中心凹改变类合计      2622
# 26                            色素脱失       764
# 27                      血管变细,动脉血管细     66483
# 28                            血管变细       459
# 29                      血管变细,静脉血管细        60
# 30                         血管变细类合计     67002
# 31                      变薄,神经纤维层变薄      1527
# 32                        变薄,黄斑区变薄       488
# 33                        变薄,视网膜变薄       134
# 34                      变薄,神经上皮层变薄        29
# 35                   变薄,视网膜色素上皮层变薄        23
# 36                           变薄类合计      2201
# 37                    色素紊乱,黄斑区色素紊乱      4087
# 38                    色素紊乱,视网膜色素紊乱       478
# 39                            色素紊乱       417
# 40                  色素紊乱,视网膜前膜色素紊乱         1
# 41                         色素紊乱类合计      4983
# 42                         裂孔,黄斑裂孔       714
# 43                              裂孔        42
# 44                        裂孔,视网膜裂孔        34
# 45                           裂孔类合计       790
# 46                   黄白色病灶,黄白色点状病灶      2762
# 47                           黄白色病灶      1818
# 48                   黄白色病灶,黄白色片状病灶       634
# 49                   黄白色病灶,黄白色团状病灶        86
# 50                   黄白色病灶,黄白色条状病灶         3
# 51                        黄白色病灶类合计      5303
# 52                           黄斑区增厚       104
# 53                             盘沿窄      8264
# 54                        皱褶,黄斑区皱褶       928
# 55                        皱褶,视网膜皱褶       594
# 56                         皱褶,前膜皱褶       145
# 57                              皱褶        34
# 58                        皱褶,脉络膜皱褶         9
# 59                         皱褶,角膜皱褶         4
# 60               皱褶,视网膜皱褶;皱褶,黄斑区皱褶         1
# 61                           皱褶类合计      1715
# 62                        血管瘤,微血管瘤      7838
# 63                         血管瘤,动脉瘤      4703
# 64                        血管瘤,微动脉瘤      2203
# 65                             血管瘤        78
# 66                 血管瘤,动脉瘤;血管瘤,动脉瘤         1
# 67                          血管瘤类合计     14823
# 68                          晶体皮质混浊     12776
# 69                           RNFLD      9637
# 70                    色素变性,黄斑区色素变性      5090
# 71                    色素变性,视网膜色素变性       678
# 72                            色素变性       474
# 73                         色素变性类合计      6242
# 74                         水肿,黄斑水肿      4018
# 75                         水肿,视盘水肿      1615
# 76                        水肿,视网膜水肿      1433
# 77                       水肿,黄斑囊样水肿       294
# 78                              水肿       265
# 79                         水肿,角膜水肿       118
# 80                         水肿,结膜水肿        87
# 81               水肿,黄斑水肿;水肿,黄斑囊样水肿        47
# 82                         水肿,眼睑水肿        35
# 83                水肿,视网膜水肿;水肿,黄斑水肿        11
# 84                 水肿,视盘水肿;水肿,黄斑水肿         6
# 85                 水肿,结膜水肿;水肿,黄斑水肿         4
# 86              水肿,视网膜水肿;水肿,黄斑囊样水肿         4
# 87                水肿,视盘水肿;水肿,视网膜水肿         2
# 88                           水肿类合计      7939
# 89                            色素沉着      1818
# 90                    色素沉着,视网膜色素沉着      1207
# 91                    色素沉着,黄斑区色素沉着       367
# 92                         色素沉着类合计      3392
# 93                           脉络膜缺损       197

# %% [markdown]
# ### 筛选——可打标眼底图像数量统计
# 筛选条件：”图像类别“==眼底图，缺少左、右眼标签，而且左、右眼疾病种类不同

# %%
# 判断左右糖网是否均为空
# pd.isnull(df_zong_yd.at[0,'left_糖网']) and pd.isnull(df_zong_yd.at[0,'right_糖网'])

# %%
# 逐行添加”未打标的含指定疾病的“，无左右眼标签，且左右眼疾病标签不同的行数据
def not_label_func(df,l_column,r_column):
    df_lr_dif = pd.DataFrame()
    for i in range(df.shape[0]):
        if pd.isnull(df.at[i,l_column]) and pd.isnull(df.at[i,r_column]):
            pass
        else:
            if df.at[i,l_column] == df.at[i,r_column]:
                pass
            else:
                df_lr_dif = df_lr_dif.append(pd.DataFrame(data=df.iloc[i:i+1,:]))
    print("左右眼异常病灶标签不一致的shape：{}".format(df_lr_dif.shape[0]))
    df_lr_weizhi = df_lr_dif[df_lr_dif['左右眼']==2]
    df_lr_isnull = df_lr_dif[df_lr_dif['左右眼'].isnull()]
    print("左右眼异常病灶标签不一致的标签数据中——左右眼==2未知的shape：{}".format(df_lr_weizhi.shape[0]))
    print("左右眼异常病灶标签不一致的标签数据中——左右眼isnull的shape：{}".format(df_lr_isnull.shape[0]))
    df_wdb = df_lr_weizhi.append(df_lr_isnull,ignore_index=True)
    print( l_column[5:]+"无左右眼，左右疾病不一致的眼底图shape：{}".format(df_wdb.shape[0]))
    return df_wdb

# %%
# df_wdb_last_0 = not_label_func(df_zong_yd,'left_玻璃膜疣','right_玻璃膜疣')

# %%
x = y

# %%
###### 绘制未打标标签表
wdb_table = pd.DataFrame(columns=['病灶子类','未打标眼底图数量'])

# %%
for i in range(len(x)):
    print('开始{}列：'.format(x[i]))
    df_wdb_last_i = not_label_func(df_zong_yd,'left_' + x[i],'right_' + x[i])
    data_i = pd.DataFrame(data={'病灶子类':[x[i]],'未打标眼底图数量':[df_wdb_last_i.shape[0]]})
    wdb_table = wdb_table.append(data_i,ignore_index=True)
    print('wdb_table的行数{}'.format(wdb_table.shape[0]))
# Out:
# 开始囊样水肿列：
# 左右眼异常病灶标签不一致的shape：784
# 左右眼异常病灶标签不一致的标签数据中——左右眼==2未知的shape：19
# 左右眼异常病灶标签不一致的标签数据中——左右眼isnull的shape：301
# 囊样水肿无左右眼，左右疾病不一致的眼底图shape：320
# wdb_table的行数24
# 开始动脉血管反光强列：
# 左右眼异常病灶标签不一致的shape：4996
# 左右眼异常病灶标签不一致的标签数据中——左右眼==2未知的shape：489
# 左右眼异常病灶标签不一致的标签数据中——左右眼isnull的shape：863
# 动脉血管反光强无左右眼，左右疾病不一致的眼底图shape：1352
# wdb_table的行数25
# 开始色素脱失列：
# 左右眼异常病灶标签不一致的shape：1123
# 左右眼异常病灶标签不一致的标签数据中——左右眼==2未知的shape：50
# 左右眼异常病灶标签不一致的标签数据中——左右眼isnull的shape：187
# 色素脱失无左右眼，左右疾病不一致的眼底图shape：237
# wdb_table的行数26
# 开始黄斑区增厚列：
# 左右眼异常病灶标签不一致的shape：259
# 左右眼异常病灶标签不一致的标签数据中——左右眼==2未知的shape：14
# 左右眼异常病灶标签不一致的标签数据中——左右眼isnull的shape：93
# 黄斑区增厚无左右眼，左右疾病不一致的眼底图shape：107
# wdb_table的行数27
# 开始盘沿窄列：
# 左右眼异常病灶标签不一致的shape：7603
# 左右眼异常病灶标签不一致的标签数据中——左右眼==2未知的shape：658
# 左右眼异常病灶标签不一致的标签数据中——左右眼isnull的shape：1280
# 盘沿窄无左右眼，左右疾病不一致的眼底图shape：1938
# wdb_table的行数28
# 开始晶体皮质混浊列：
# 左右眼异常病灶标签不一致的shape：2823
# 左右眼异常病灶标签不一致的标签数据中——左右眼==2未知的shape：577
# 左右眼异常病灶标签不一致的标签数据中——左右眼isnull的shape：696
# 晶体皮质混浊无左右眼，左右疾病不一致的眼底图shape：1273
# wdb_table的行数29
# 开始RNFLD列：
# 左右眼异常病灶标签不一致的shape：6659
# 左右眼异常病灶标签不一致的标签数据中——左右眼==2未知的shape：348
# 左右眼异常病灶标签不一致的标签数据中——左右眼isnull的shape：955
# RNFLD无左右眼，左右疾病不一致的眼底图shape：1303
# wdb_table的行数30

# %%
wdb_table   # 未打标疾病标签统计
# Out:
#           病灶子类 未打标眼底图数量
# 0      血管闭塞类合计     1285
# 1      囊样水肿类合计      320
# 2        脱离类合计     1355
# 3      血管硬化类合计     1909
# 4   动脉血管反光强类合计     1352
# 5     中心凹改变类合计      324
# 6      色素脱失类合计      237
# 7      血管变细类合计     4559
# 8        变薄类合计      522
# 9      色素紊乱类合计     1124
# 10       裂孔类合计      499
# 11        血管异常       88
# 12    黄白色病灶类合计     1317
# 13    黄斑区增厚类合计      107
# 14      盘沿窄类合计     1938
# 15       皱褶类合计      637
# 16      血管瘤类合计     1252
# 17   晶体皮质混浊类合计     1273
# 18    RNFLD类合计     1303
# 19     色素变性类合计     1076
# 20       水肿类合计     3828
# 21     色素沉着类合计      730
# 22    脉络膜缺损类合计       55
# 23        囊样水肿      320
# 24     动脉血管反光强     1352
# 25        色素脱失      237
# 26       黄斑区增厚      107
# 27         盘沿窄     1938
# 28      晶体皮质混浊     1273
# 29       RNFLD     1303

# %%
# 定义——添加后缀“类合计”的列名list ——排除单一行的情况
z = ['血管闭塞', '脱离', '血管硬化', '中心凹改变', '血管变细', '变薄',
     '色素紊乱', '裂孔', '黄白色病灶','黄斑区增厚', '盘沿窄', '皱褶', '血管瘤', '色素变性',
     '水肿']

# %%
# 为“大类标签”添加后缀“”类
for i in range(len(z)):
    wdb_table['病灶子类'] = wdb_table['病灶子类'].replace(z[i],value=z[i]+'类合计')

# %%
ydb_table  # # 已打标疾病标签统计
# Out:
#                               病灶子类  已打标眼底图数量
# 0                             血管闭塞      1676
# 1                        血管闭塞,动脉闭塞       823
# 2                        血管闭塞,静脉闭塞       315
# 3                          血管闭塞类合计      2814
# 4                             囊样水肿       347
# 5                       脱离,神经上皮层脱离       906
# 6                         脱离,视网膜脱离       698
# 7                        脱离,玻璃体后脱离       305
# 8                          脱离,黄斑脱离       133
# 9                       脱离,色素上皮层脱离        82
# 10             脱离,视网膜脱离;脱离,神经上皮层脱离        19
# 11              脱离,黄斑脱离;脱离,神经上皮层脱离         6
# 12                      脱离,神经纤维层脱离         3
# 13  脱离,视网膜脱离;脱离,神经上皮层脱离;脱离,色素上皮层脱离         2
# 89                            色素沉着      1818
# 90                    色素沉着,视网膜色素沉着      1207
# 91                    色素沉着,黄斑区色素沉着       367
# 92                         色素沉着类合计      3392
# 93                           脉络膜缺损       197

# %%
# 最终的结果统计表
statistic_table = pd.merge(ydb_table,wdb_table,how='left',on='病灶子类')
statistic_table
# Out:
#                               病灶子类  已打标眼底图数量 未打标眼底图数量
# 0                             血管闭塞      1676      NaN
# 1                        血管闭塞,动脉闭塞       823      NaN
# 2                        血管闭塞,静脉闭塞       315      NaN
# 3                          血管闭塞类合计      2814     1285
# 4                             囊样水肿       347      320
# 5                       脱离,神经上皮层脱离       906      NaN
# 6                         脱离,视网膜脱离       698      NaN
# 7                        脱离,玻璃体后脱离       305      NaN
# 8                          脱离,黄斑脱离       133      NaN
# 9                       脱离,色素上皮层脱离        82      NaN
# 10             脱离,视网膜脱离;脱离,神经上皮层脱离        19      NaN
# 11              脱离,黄斑脱离;脱离,神经上皮层脱离         6      NaN
# 12                      脱离,神经纤维层脱离         3      NaN
# 13  脱离,视网膜脱离;脱离,神经上皮层脱离;脱离,色素上皮层脱离         2      NaN
# 14   脱离,黄斑脱离;脱离,神经上皮层脱离;脱离,色素上皮层脱离         1      NaN
# 15                           脱离类合计      2155     1355
# 16                       血管硬化,动脉硬化     35424      NaN
# 17                            血管硬化        20      NaN
# 18                         血管硬化类合计     35444     1909
# 19                         动脉血管反光强     16045     1352
# 20                   中心凹改变,中心凹反光消失      1795      NaN
# 21                   中心凹改变,中心凹反光不清       773      NaN
# 22                   中心凹改变,中心凹反光弥散        48      NaN
# 23                   中心凹改变,中心凹反光增强         4      NaN
# 24                     中心凹改变,中心凹变平         2      NaN
# 25                        中心凹改变类合计      2622      324
# 26                            色素脱失       764      237
# 27                      血管变细,动脉血管细     66483      NaN
# 28                            血管变细       459      NaN
# 29                      血管变细,静脉血管细        60      NaN
# 30                         血管变细类合计     67002     4559
# 31                      变薄,神经纤维层变薄      1527      NaN
# 32                        变薄,黄斑区变薄       488      NaN
# 33                        变薄,视网膜变薄       134      NaN
# 34                      变薄,神经上皮层变薄        29      NaN
# 35                   变薄,视网膜色素上皮层变薄        23      NaN
# 36                           变薄类合计      2201      522
# 37                    色素紊乱,黄斑区色素紊乱      4087      NaN
# 38                    色素紊乱,视网膜色素紊乱       478      NaN
# 39                            色素紊乱       417      NaN
# 40                  色素紊乱,视网膜前膜色素紊乱         1      NaN
# 41                         色素紊乱类合计      4983     1124
# 42                         裂孔,黄斑裂孔       714      NaN
# 43                              裂孔        42      NaN
# 44                        裂孔,视网膜裂孔        34      NaN
# 45                           裂孔类合计       790      499
# 46                   黄白色病灶,黄白色点状病灶      2762      NaN
# 47                           黄白色病灶      1818      NaN
# 48                   黄白色病灶,黄白色片状病灶       634      NaN
# 49                   黄白色病灶,黄白色团状病灶        86      NaN
# 50                   黄白色病灶,黄白色条状病灶         3      NaN
# 51                        黄白色病灶类合计      5303     1317
# 52                           黄斑区增厚       104      107
# 53                             盘沿窄      8264     1938
# 54                        皱褶,黄斑区皱褶       928      NaN
# 55                        皱褶,视网膜皱褶       594      NaN
# 56                         皱褶,前膜皱褶       145      NaN
# 57                              皱褶        34      NaN
# 58                        皱褶,脉络膜皱褶         9      NaN
# 59                         皱褶,角膜皱褶         4      NaN
# 60               皱褶,视网膜皱褶;皱褶,黄斑区皱褶         1      NaN
# 61                           皱褶类合计      1715      637
# 62                        血管瘤,微血管瘤      7838      NaN
# 63                         血管瘤,动脉瘤      4703      NaN
# 64                        血管瘤,微动脉瘤      2203      NaN
# 65                             血管瘤        78      NaN
# 66                 血管瘤,动脉瘤;血管瘤,动脉瘤         1      NaN
# 67                          血管瘤类合计     14823     1252
# 68                          晶体皮质混浊     12776     1273
# 69                           RNFLD      9637     1303
# 70                    色素变性,黄斑区色素变性      5090      NaN
# 71                    色素变性,视网膜色素变性       678      NaN
# 72                            色素变性       474      NaN
# 73                         色素变性类合计      6242     1076
# 74                         水肿,黄斑水肿      4018      NaN
# 75                         水肿,视盘水肿      1615      NaN
# 76                        水肿,视网膜水肿      1433      NaN
# 77                       水肿,黄斑囊样水肿       294      NaN
# 78                              水肿       265      NaN
# 79                         水肿,角膜水肿       118      NaN
# 80                         水肿,结膜水肿        87      NaN
# 81               水肿,黄斑水肿;水肿,黄斑囊样水肿        47      NaN
# 82                         水肿,眼睑水肿        35      NaN
# 83                水肿,视网膜水肿;水肿,黄斑水肿        11      NaN
# 84                 水肿,视盘水肿;水肿,黄斑水肿         6      NaN
# 85                 水肿,结膜水肿;水肿,黄斑水肿         4      NaN
# 86              水肿,视网膜水肿;水肿,黄斑囊样水肿         4      NaN
# 87                水肿,视盘水肿;水肿,视网膜水肿         2      NaN
# 88                           水肿类合计      7939     3828
# 89                            色素沉着      1818      NaN
# 90                    色素沉着,视网膜色素沉着      1207      NaN
# 91                    色素沉着,黄斑区色素沉着       367      NaN
# 92                         色素沉着类合计      3392      730
# 93                           脉络膜缺损       197      NaN

# %%
statistic_table['可打标眼底图数量'] = statistic_table.loc[:,['已打标眼底图数量','未打标眼底图数量']].apply(lambda x: x.sum(),axis=1)
# 将数据类型转为int型
statistic_table[['已打标眼底图数量','可打标眼底图数量']] = statistic_table[['已打标眼底图数量','可打标眼底图数量']].astype(int)

# %%
# statistic_table.drop_duplicates(subset='疾病子类',keep='first',inplace=True)
# statistic_table.reset_index(drop=True,inplace=True)
statistic_table
# Out:
#                               病灶子类  已打标眼底图数量 未打标眼底图数量  可打标眼底图数量
# 0                             血管闭塞      1676      NaN      1676
# 1                        血管闭塞,动脉闭塞       823      NaN       823
# 2                        血管闭塞,静脉闭塞       315      NaN       315
# 3                          血管闭塞类合计      2814     1285      4099
# 4                             囊样水肿       347      320       667
# 5                       脱离,神经上皮层脱离       906      NaN       906
# 6                         脱离,视网膜脱离       698      NaN       698
# 7                        脱离,玻璃体后脱离       305      NaN       305
# 8                          脱离,黄斑脱离       133      NaN       133
# 9                       脱离,色素上皮层脱离        82      NaN        82
# 10             脱离,视网膜脱离;脱离,神经上皮层脱离        19      NaN        19
# 68                          晶体皮质混浊     12776     1273     14049
# 69                           RNFLD      9637     1303     10940
# 70                    色素变性,黄斑区色素变性      5090      NaN      5090
# 71                    色素变性,视网膜色素变性       678      NaN       678
# 72                            色素变性       474      NaN       474
# 73                         色素变性类合计      6242     1076      7318
# 74                         水肿,黄斑水肿      4018      NaN      4018
# 75                         水肿,视盘水肿      1615      NaN      1615
# 76                        水肿,视网膜水肿      1433      NaN      1433
# 77                       水肿,黄斑囊样水肿       294      NaN       294
# 78                              水肿       265      NaN       265
# 79                         水肿,角膜水肿       118      NaN       118
# 80                         水肿,结膜水肿        87      NaN        87
# 81               水肿,黄斑水肿;水肿,黄斑囊样水肿        47      NaN        47
# 82                         水肿,眼睑水肿        35      NaN        35
# 83                水肿,视网膜水肿;水肿,黄斑水肿        11      NaN        11
# 84                 水肿,视盘水肿;水肿,黄斑水肿         6      NaN         6
# 85                 水肿,结膜水肿;水肿,黄斑水肿         4      NaN         4
# 86              水肿,视网膜水肿;水肿,黄斑囊样水肿         4      NaN         4
# 87                水肿,视盘水肿;水肿,视网膜水肿         2      NaN         2
# 88                           水肿类合计      7939     3828     11767
# 89                            色素沉着      1818      NaN      1818
# 90                    色素沉着,视网膜色素沉着      1207      NaN      1207
# 91                    色素沉着,黄斑区色素沉着       367      NaN       367
# 92                         色素沉着类合计      3392      730      4122
# 93                           脉络膜缺损       197      NaN       197

# %%
statistic_table['已打标眼底图数量/总眼底图的占比'] = statistic_table['已打标眼底图数量']/df_zong_yd.shape[0]
statistic_table['已打标眼底图数量/可打标眼底图的占比'] = statistic_table['已打标眼底图数量']/statistic_table['可打标眼底图数量']
# 设置显示格式为百分比
statistic_table['已打标眼底图数量/总眼底图的占比'] = statistic_table['已打标眼底图数量/总眼底图的占比'].map(lambda x:format(x,'.2%'))
statistic_table['已打标眼底图数量/可打标眼底图的占比'] = statistic_table['已打标眼底图数量/可打标眼底图的占比'].map(lambda x:format(x,'.2%'))

# %%
df_zong_yd.shape[0]
# Out:
# 504334

# %% [markdown]
# ### 导出最终的结果统计表

# %%
out_put_path = r'/Users/edz/Documents/yandi_data/AI_data/标签汇总表'
out_put_file = r'/眼底图像异常病灶_打标情况统计表_demo输出hou.xlsx'
writer = pd.ExcelWriter(out_put_path + out_put_file)
statistic_table.to_excel(writer,sheet_name='眼底图像异常病灶_打标情况统计表',index=None)
writer.save()

# %%
197+55
# Out:
# 252

# %% [markdown]
# ### 绘制条形图

# %%
da = ydb_table[ydb_table['疾病子类'].str.contains('类合计')]

# %%
zi_df = ydb_table.append(da)

# %%
zi_df.drop_duplicates(subset='疾病子类',keep=False,inplace=True)

# %%
zi_df['已打标眼底图数量'] = zi_df['已打标眼底图数量'].astype(int)
zi_df.sort_values(by='已打标眼底图数量',inplace=True,ascending=False)
zi_df.reset_index(drop=True,inplace=True)
zi_df

# %%
zi_df_top30 =zi_df.iloc[:30,:] 
zi_df_top30

# %%
output_path = r'/Users/edz/Documents/yandi_data/AI_data/标签汇总表'
output_file = r'/疾病190子类条形图_top30.xlsx'
writer = pd.ExcelWriter(output_path + output_file)
zi_df.to_excel(writer,sheet_name='疾病190种子类条形图_全',index=None)
zi_df_top30.to_excel(writer,sheet_name='疾病190子类条形图Top30',index=None)
writer.save()

# %% [markdown]
# ### 绘制疾病标签占比饼图

# %%
# 选取含”类合计“的项
da_data = ydb_table[ydb_table['疾病子类'].str.contains('类合计')]
# 合并“糖、青、白”
da_data_add = ydb_table.loc[0:2,:]
da_data = da_data.append(da_data_add, ignore_index=True) 
da_data

# %%
da_data['已打标眼底图数量'] = da_data['已打标眼底图数量'].astype(int)
da_data = da_data.sort_values(by='已打标眼底图数量', ascending=False)

# %%
# pandas.Series.str.replace进行局部名称替换
da_data['疾病子类'] = da_data['疾病子类'].str.replace('合计','',regex=True)

# %%
da_data.drop_duplicates(subset="疾病子类",keep='first',inplace=True)
da_data.reset_index(drop=True,inplace=True)

# %%
da_data

# %%
da_data_top30 = da_data.iloc[:30,:] 
da_data_top30

# %%
output_path = r'/Users/edz/Documents/yandi_data/AI_data/标签汇总表'
output_file = r'/59大类眼底疾病条形图_top30.xlsx'
writer = pd.ExcelWriter(output_path + output_file)
da_data.to_excel(writer,sheet_name='59大类眼底疾病条形图_全',index=None)
da_data_top30.to_excel(writer,sheet_name='59大类眼底疾病条形图Top30',index=None)
writer.save()

# %% [markdown]
# ### 绘图

# %%
from pylab import *
mpl.rcParams['font.sans-serif'] = ['Songti SC']
mpl.rcParams['axes.unicode_minus'] = False
# %matplotlib inline
from IPython import display
from matplotlib import pyplot as plt
import seaborn as sns
import scipy.stats as sci

# %%
def auto_text(rects):
    for rect in rects:
        ax.text(rect.get_x(), rect.get_height(), rect.get_height(), ha='left', va='bottom')

# %%
# 设置图片大小
plt.figure(figsize=(20, 18))
# pal = sns.color_palette("Greens_d",len(da_data_top30['疾病子类'])
# 绘制水平图
sns.set(context='notebook',style='darkgrid',palette='deep',font='Songti SC',font_scale=1.2)
ax = sns.barplot( da_data_top30['疾病子类'],da_data_top30['已打标眼底图数量'],palette="Set1")
plt.xlabel('已打标眼底图数量',fontsize=15)
plt.ylabel('疾病子类',fontsize=15)

for column,row in da_data_top30.iterrows():
#     print(row)
    ax.text(row.疾病子类,row.已打标眼底图数量,'row.已打标眼底图数量')

# #为横向水平的柱图右侧添加数据标签。
# for rect in rect1 :
#     w = rect.get_hight()
#     ax.text(rect.get_x(), rect.get_height(), rect.get_height(), ha='left', va='bottom')

plt.show()

# %%
# ax[0].get_height()
 for rect in rect1 :
    w = rect.get_hight()
    ax.text(rect.get_x(), rect.get_height(), rect.get_height(), ha='left', va='bottom')

# %%
da_data_top30

# %%
for column,row in da_data_top30.iterrows():
    print(row.已打标眼底图数量)
# ax.text(row.疾病子类,row.已打标眼底图数量)

# %%
 for index,row in da_data_top30['已打标眼底图数量'].iterrows():
        print(index,row)

# %%
city_name = da_data_top30['疾病子类'].to_list
city_name

# %%
# 添加占比数据列
a = statistic_table
a['已打标眼底图数量/总眼底图的占比'] = a['已打标眼底图数量']/df_zong_yd.shape[0]
a['已打标眼底图数量/可打标眼底图的占比'] = a['已打标眼底图数量']/a['可打标眼底图数量']
# 设置显示格式为百分比
a['已打标眼底图数量/总眼底图的占比'] = a['已打标眼底图数量/总眼底图的占比'].map(lambda x:format(x,'.2%'))
a['已打标眼底图数量/可打标眼底图的占比'] = a['已打标眼底图数量/可打标眼底图的占比'].map(lambda x:format(x,'.2%'))

# %%
df_zong_yd.shape[0]

# %%
plt.pie(x, label, explode,shadow=True,pctdistance=0.6,labeldistance=1.1，startangle=90) # explode表示部分扇形突出，x,label,explode均为数组形式数据

# %%
b = a[['疾病子类','已打标眼底图数量/可打标眼底图的占比']]

# %%
c = b.drop([x for x in range(3,11)],axis=0)

# %%
c = c.drop([x for x in range(34,42)],axis=0)
c

# %%
c

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['STHeiti'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
matplotlib.matplotlib_fname()  # 确认字体的安装目录

# %%
from matplotlib import font_manager
x = sorted([f.name for f in font_manager.fontManager.ttflist])
for i in x:
    print(i)

# %%
plt.rcParams['font.sans-serif']=['STHeiti'] #用来正常显示中文标签

# %%
d = a[['疾病子类','已打标眼底图数量/总眼底图的占比']]

# %%
d = d.drop([11,15,33,42],axis=0)
d

# %%
# Hiragino Sans GB
# Songti SC
# Heiti TC
# PingFang HK
# Songti SC
import matplotlib

font = {'family' : 'Songti SC',
        'weight' : 'bold',
        'size'   : 10}
matplotlib.rc("font", **font)

# %%
plt.rc(font)
fig = plt.figure()
plt.pie(d['已打标眼底图数量/总眼底图的占比'],labels=d['疾病子类'],autopct='%1.2f%%') #画饼图（数据，数据对应的标签，百分数保留两位小数点）
plt.title("已打标眼底图数量/总眼底图的占比分布")
plt.show()

# %% [markdown]
# ### 导出没有32分类标签的原始数据，并拆分为6份

# %%
# 导出没有32分类标签的原始数据
df_zong.shape

# %%
df_zong.columns

# %%
no_label = df_zong[['图像地址','arithmeticTag']]

# %%
no_label = no_label[~no_label['图像地址'].str.contains('empty|invalid')]

# %%
no_label = no_label[no_label['arithmeticTag'].isnull()]

# %%
no_label[no_label['图像地址'].duplicated()==True]['图像地址'].value_counts()

# %%
no_label.drop_duplicates(subset='图像地址',keep='first',inplace=True)

# %%
no_label['bucket'] = 'zhizhen-tms'

# %%
no_label.tail(2)

# %%
no_label.shape[0]

# %%
6*52400-366554

# %%
no_label.drop(columns=['arithmeticTag'],inplace=True)

# %%
no_label.rename(columns={'图像地址':'objectkey'},inplace=True)

# %%
no_label.reset_index(drop=True,inplace=True)

# %%
# 拆分数据表
start_x = 0
end_x = 52400
temp_size = 52400
for i in range(7):
    print(start_x,end_x)
    df_x = no_label.loc[start_x:end_x,:]
    print(df_x.shape[0])
    output_path = r'/Users/edz/Documents/yandi_data/AI_data/32分类标签/原始数据'
    output_path_file = r'/noclassific_part_' + str(i) + '.txt' 
    df_x.to_csv(output_path+output_path_file,sep='\t',index=None)
#     writer = pd.ExcelWriter(output_path+output_path_file)
#     df_x.to_excel(writer,sheet_name=str(start_x)+"-"+str(end_x),index=None)
#     writer.save()
    
    start_x += temp_size
    end_x += temp_size
